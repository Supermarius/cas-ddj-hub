# %%
from bs4 import BeautifulSoup
import os
import pandas as pd
import re

# %%
list_df = []

# %%
allefiles = os.listdir("simap1_2019")

# %%
def my_function(input): 
    
    vergabestelle = str(soup.find_all("td")[0].find_all("dd")[2])
    vergabestelle = vergabestelle.replace("\n", " ")
    vergabestelle = vergabestelle.replace("\xa0", " ")
    regex1 = r"(?<=<\/span>\s).*(?=<br\/><span)"
    vergabestelle = re.findall(regex1, vergabestelle)[0]
    
    verfahren = (soup.find_all("td")[0].find_all("dd")[4].text)
    verfahren = verfahren.replace("\n", "")
    verfahren = verfahren.replace("\t", "")
    
    projekt = soup.find_all("td")[0].find_all("dd")[7].text
    
    try:
        projekttyp = soup.find_all("td")[0].find_all("dd")[8].text
        projekttyp = projekttyp.replace("\xa0", " ") 
        regex2 = r"(?<=-\s).*"
        projekttyp = re.findall(regex2, projekttyp)[0]
    except:
        projekttyp = soup.find_all("td")[0].find_all("dd")[10].text
        projekttyp = projekttyp.replace("\xa0", " ") 
        regex2 = r"(?<=-\s).*(?=\s\(BKP)"
        projekttyp = re.findall(regex2, projekttyp)[0]

    try:
        anbieter = soup.find_all("td")[0].find_all("dd")[9].text
        anbieter = anbieter.replace("\n", "")
        anbieter = anbieter.replace("\t", "")
        anbieter = anbieter.replace("\xa0", " ")
        regex3 = r"(?<=Name:\s).*(?=,)"
        anbieter = re.findall(regex3, anbieter)[0]
        anbieter = anbieter.split(",")
    except:
        anbieter = soup.find_all("td")[0].find_all("dd")[11].text
        anbieter = anbieter.replace("\n", "")
        anbieter = anbieter.replace("\t", "")
        anbieter = anbieter.replace("\xa0", " ")
        regex3 = r"(?<=Name:\s).*(?=,)"
        anbieter = re.findall(regex3, anbieter)[0]
        anbieter = anbieter.split(",")

    anbieter_name = anbieter[0].strip()
    anbieter_adr1 = anbieter[1].strip()
    anbieter_adr2 = anbieter[1].strip()
    
    try: 
        preis = soup.find_all("td")[0].find_all("dd")[9].text
        preis = preis.replace("\n", "")
        preis = preis.replace("\t", "")
        preis = preis.replace("\xa0", " ")
        regex4 = r"\d*'*\d*'*\d*'*\d*\.\d\d"
        preis = re.findall(regex4, preis)
        preis = float(preis[0].replace("'",""))
    except:
        preis = soup.find_all("td")[0].find_all("dd")[11].text
        preis = preis.replace("\n", "")
        preis = preis.replace("\t", "")
        preis = preis.replace("\xa0", " ")
        regex4 = r"\d*'*\d*'*\d*'*\d*\.\d\d"
        preis = re.findall(regex4, preis)
        preis = float(preis[0].replace("'",""))
    
    mini_dict = {"Vergabestelle" : vergabestelle,
                 "Preis" : preis,
                 "Anbieter" : "anbieter_name",
                 "Typ" : projekttyp,
                 "Verfahren" : verfahren,
                 "Projekt" : projekt,
                 "Adresse" : anbieter_adr1 + ", " + anbieter_adr2}
    return mini_dict

# %%
#test mit einem File

data = open("simap1_2019/"+str(allefiles[188]), "r")
text = data.read()
soup = BeautifulSoup(text, "html.parser")

list_df.append(my_function(soup))

list_df
# Out:
# [{'Vergabestelle': 'Stadt Zürich',
#   'Preis': 430312.85,
#   'Anbieter': 'anbieter_name',
#   'Typ': 'Bauleistungen im HochbauBaukostenplannummer (BKP): 2711 - Spezielle Gipserarbeiten',
#   'Verfahren': 'Offenes Verfahren',
#   'Projekt': 'BAV 40165 Alterszentrum Laubegg',
#   'Adresse': 'Strengelbacherstrasse 2, Strengelbacherstrasse 2'}]

# %%
for file in allefiles:
   
    data = open("simap1_2019/"+str(file), "r")
    text = data.read()
    soup = BeautifulSoup(text, "html.parser")
    
    print(file)
    list_df.append(my_function(soup))
# Out:
# zuschlag768.htm
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-50cbbd601038> in <module>
#       6
#       7     print(file)
# ----> 8     list_df.append(my_function(soup))
#       9
#
# <ipython-input-4-1a1a2cdfe679> in my_function(input)
#       5     vergabestelle = vergabestelle.replace("\xa0", " ")
#       6     regex1 = r"(?<=<\/span>\s).*(?=<br\/><span)"
# ----> 7     vergabestelle = re.findall(regex1, vergabestelle)[0]
#       8
#       9     verfahren = (soup.find_all("td")[0].find_all("dd")[4].text)
#
# IndexError: list index out of range

# %%
allefiles
# Out:
# ['zuschlag768.htm',
#  'zuschlag2393.htm',
#  'zuschlag1842.htm',
#  'zuschlag1856.htm',
#  'zuschlag3099.htm',
#  'zuschlag2387.htm',
#  'zuschlag754.htm',
#  'zuschlag740.htm',
#  'zuschlag998.htm',
#  'zuschlag2436.htm',
#  'zuschlag973.htm',
#  'zuschlag1881.htm',
#  'zuschlag1659.htm',
#  'zuschlag2350.htm',
#  'zuschlag2344.htm',
#  'zuschlag1895.htm',
#  'zuschlag967.htm',
#  'zuschlag2422.htm',
#  'zuschlag1103.htm',
#  'zuschlag797.htm',
#  'zuschlag3072.htm',
#  'zuschlag1665.htm',
#  'zuschlag1671.htm',
#  'zuschlag2378.htm',
#  'zuschlag3066.htm',
#  'zuschlag1117.htm',
#  'zuschlag783.htm',
#  'zuschlag1498.htm',
#  'zuschlag2191.htm',
#  'zuschlag58.htm',
#  'zuschlag2185.htm',
#  'zuschlag218.htm',
#  'zuschlag230.htm',
#  'zuschlag556.htm',
#  'zuschlag70.htm',
#  'zuschlag2813.htm',
#  'zuschlag2807.htm',
#  'zuschlag64.htm',
#  'zuschlag542.htm',
#  'zuschlag224.htm',
#  'zuschlag2152.htm',
#  'zuschlag2634.htm',
#  'zuschlag2620.htm',
#  'zuschlag1329.htm',
#  'zuschlag2146.htm',
#  'zuschlag1467.htm',
#  'zuschlag2608.htm',
#  'zuschlag595.htm',
#  'zuschlag1301.htm',
#  'zuschlag581.htm',
#  'zuschlag1315.htm',
#  'zuschlag1473.htm',
#  'zuschlag378.htm',
#  'zuschlag2783.htm',
#  'zuschlag2797.htm',
#  'zuschlag344.htm',
#  'zuschlag422.htm',
#  'zuschlag2967.htm',
#  'zuschlag2973.htm',
#  'zuschlag436.htm',
#  'zuschlag350.htm',
#  'zuschlag2026.htm',
#  'zuschlag1249.htm',
#  'zuschlag2998.htm',
#  'zuschlag2740.htm',
#  'zuschlag2754.htm',
#  'zuschlag2032.htm',
#  'zuschlag387.htm',
#  'zuschlag1513.htm',
#  'zuschlag1275.htm',
#  'zuschlag1261.htm',
#  'zuschlag2768.htm',
#  'zuschlag393.htm',
#  'zuschlag1507.htm',
#  'zuschlag1088.htm',
#  'zuschlag2581.htm',
#  'zuschlag1936.htm',
#  'zuschlag1922.htm',
#  'zuschlag2595.htm',
#  'zuschlag608.htm',
#  'zuschlag620.htm',
#  'zuschlag146.htm',
#  'zuschlag152.htm',
#  'zuschlag634.htm',
#  'zuschlag2542.htm',
#  'zuschlag807.htm',
#  'zuschlag2224.htm',
#  'zuschlag2230.htm',
#  'zuschlag1739.htm',
#  'zuschlag813.htm',
#  'zuschlag2556.htm',
#  'zuschlag1077.htm',
#  'zuschlag3106.htm',
#  'zuschlag2218.htm',
#  'zuschlag1711.htm',
#  'zuschlag185.htm',
#  'zuschlag1705.htm',
#  'zuschlag191.htm',
#  'zuschlag3112.htm',
#  'zuschlag1063.htm',
#  'zuschlag3113.htm',
#  'zuschlag190.htm',
#  'zuschlag1704.htm',
#  'zuschlag1062.htm',
#  'zuschlag1076.htm',
#  'zuschlag184.htm',
#  'zuschlag1710.htm',
#  'zuschlag2219.htm',
#  'zuschlag3107.htm',
#  'zuschlag1738.htm',
#  'zuschlag2231.htm',
#  'zuschlag2557.htm',
#  'zuschlag812.htm',
#  'zuschlag806.htm',
#  'zuschlag2543.htm',
#  'zuschlag2225.htm',
#  'zuschlag153.htm',
#  'zuschlag635.htm',
#  'zuschlag621.htm',
#  'zuschlag147.htm',
#  'zuschlag1923.htm',
#  'zuschlag609.htm',
#  'zuschlag2594.htm',
#  'zuschlag2580.htm',
#  'zuschlag1089.htm',
#  'zuschlag1937.htm',
#  'zuschlag2769.htm',
#  'zuschlag1260.htm',
#  'zuschlag1506.htm',
#  'zuschlag392.htm',
#  'zuschlag1512.htm',
#  'zuschlag386.htm',
#  'zuschlag1274.htm',
#  'zuschlag2755.htm',
#  'zuschlag2033.htm',
#  'zuschlag2027.htm',
#  'zuschlag2741.htm',
#  'zuschlag2999.htm',
#  'zuschlag1248.htm',
#  'zuschlag437.htm',
#  'zuschlag2972.htm',
#  'zuschlag351.htm',
#  'zuschlag345.htm',
#  'zuschlag2966.htm',
#  'zuschlag423.htm',
#  'zuschlag2796.htm',
#  'zuschlag379.htm',
#  'zuschlag2782.htm',
#  'zuschlag1314.htm',
#  'zuschlag580.htm',
#  'zuschlag1472.htm',
#  'zuschlag1466.htm',
#  'zuschlag1300.htm',
#  'zuschlag594.htm',
#  'zuschlag2609.htm',
#  'zuschlag1328.htm',
#  'zuschlag2621.htm',
#  'zuschlag2147.htm',
#  'zuschlag2153.htm',
#  'zuschlag2635.htm',
#  'zuschlag543.htm',
#  'zuschlag65.htm',
#  'zuschlag2806.htm',
#  'zuschlag225.htm',
#  'zuschlag231.htm',
#  'zuschlag2812.htm',
#  'zuschlag71.htm',
#  'zuschlag557.htm',
#  'zuschlag59.htm',
#  'zuschlag219.htm',
#  'zuschlag2184.htm',
#  'zuschlag2190.htm',
#  'zuschlag1499.htm',
#  'zuschlag3067.htm',
#  'zuschlag2379.htm',
#  'zuschlag1670.htm',
#  'zuschlag782.htm',
#  'zuschlag1116.htm',
#  'zuschlag796.htm',
#  'zuschlag1102.htm',
#  'zuschlag1664.htm',
#  'zuschlag3073.htm',
#  'zuschlag1894.htm',
#  'zuschlag2345.htm',
#  'zuschlag2423.htm',
#  'zuschlag966.htm',
#  'zuschlag972.htm',
#  'zuschlag2437.htm',
#  'zuschlag2351.htm',
#  'zuschlag1658.htm',
#  'zuschlag1880.htm',
#  'zuschlag999.htm',
#  'zuschlag741.htm',
#  'zuschlag755.htm',
#  'zuschlag2386.htm',
#  'zuschlag3098.htm',
#  'zuschlag1857.htm',
#  'zuschlag769.htm',
#  'zuschlag1843.htm',
#  'zuschlag2392.htm',
#  'zuschlag1855.htm',
#  'zuschlag2384.htm',
#  'zuschlag2390.htm',
#  'zuschlag1699.htm',
#  'zuschlag1841.htm',
#  'zuschlag743.htm',
#  'zuschlag1869.htm',
#  'zuschlag757.htm',
#  'zuschlag964.htm',
#  'zuschlag1128.htm',
#  'zuschlag2421.htm',
#  'zuschlag2347.htm',
#  'zuschlag3059.htm',
#  'zuschlag1896.htm',
#  'zuschlag1882.htm',
#  'zuschlag2353.htm',
#  'zuschlag2435.htm',
#  'zuschlag970.htm',
#  'zuschlag958.htm',
#  'zuschlag1114.htm',
#  'zuschlag780.htm',
#  'zuschlag1672.htm',
#  'zuschlag3065.htm',
#  'zuschlag3071.htm',
#  'zuschlag1666.htm',
#  'zuschlag1100.htm',
#  'zuschlag794.htm',
#  'zuschlag2409.htm',
#  'zuschlag2186.htm',
#  'zuschlag2838.htm',
#  'zuschlag569.htm',
#  'zuschlag2192.htm',
#  'zuschlag227.htm',
#  'zuschlag2804.htm',
#  'zuschlag67.htm',
#  'zuschlag541.htm',
#  'zuschlag555.htm',
#  'zuschlag73.htm',
#  'zuschlag2810.htm',
#  'zuschlag233.htm',
#  'zuschlag2145.htm',
#  'zuschlag2623.htm',
#  'zuschlag98.htm',
#  'zuschlag2637.htm',
#  'zuschlag2151.htm',
#  'zuschlag1458.htm',
#  'zuschlag2179.htm',
#  'zuschlag1470.htm',
#  'zuschlag582.htm',
#  'zuschlag1316.htm',
#  'zuschlag596.htm',
#  'zuschlag1302.htm',
#  'zuschlag1464.htm',
#  'zuschlag409.htm',
#  'zuschlag2794.htm',
#  'zuschlag2780.htm',
#  'zuschlag2958.htm',
#  'zuschlag1289.htm',
#  'zuschlag353.htm',
#  'zuschlag2970.htm',
#  'zuschlag435.htm',
#  'zuschlag421.htm',
#  'zuschlag2964.htm',
#  'zuschlag347.htm',
#  'zuschlag1538.htm',
#  'zuschlag2031.htm',
#  'zuschlag2757.htm',
#  'zuschlag2743.htm',
#  'zuschlag2025.htm',
#  'zuschlag390.htm',
#  'zuschlag1504.htm',
#  'zuschlag1262.htm',
#  'zuschlag1276.htm',
#  'zuschlag384.htm',
#  'zuschlag1510.htm',
#  'zuschlag2019.htm',
#  'zuschlag2596.htm',
#  'zuschlag1921.htm',
#  'zuschlag179.htm',
#  'zuschlag1935.htm',
#  'zuschlag2582.htm',
#  'zuschlag637.htm',
#  'zuschlag151.htm',
#  'zuschlag145.htm',
#  'zuschlag1909.htm',
#  'zuschlag623.htm',
#  'zuschlag810.htm',
#  'zuschlag2555.htm',
#  'zuschlag2233.htm',
#  'zuschlag3139.htm',
#  'zuschlag2227.htm',
#  'zuschlag2541.htm',
#  'zuschlag1048.htm',
#  'zuschlag804.htm',
#  'zuschlag2569.htm',
#  'zuschlag1060.htm',
#  'zuschlag1706.htm',
#  'zuschlag192.htm',
#  'zuschlag3111.htm',
#  'zuschlag3105.htm',
#  'zuschlag1712.htm',
#  'zuschlag186.htm',
#  'zuschlag1074.htm',
#  'zuschlag838.htm',
#  'zuschlag187.htm',
#  'zuschlag1713.htm',
#  'zuschlag3104.htm',
#  'zuschlag839.htm',
#  'zuschlag1075.htm',
#  'zuschlag1061.htm',
#  'zuschlag2568.htm',
#  'zuschlag3110.htm',
#  'zuschlag193.htm',
#  'zuschlag1707.htm',
#  'zuschlag2226.htm',
#  'zuschlag3138.htm',
#  'zuschlag805.htm',
#  'zuschlag1049.htm',
#  'zuschlag2540.htm',
#  'zuschlag2554.htm',
#  'zuschlag811.htm',
#  'zuschlag2232.htm',
#  'zuschlag1908.htm',
#  'zuschlag144.htm',
#  'zuschlag622.htm',
#  'zuschlag636.htm',
#  'zuschlag150.htm',
#  'zuschlag1934.htm',
#  'zuschlag178.htm',
#  'zuschlag2583.htm',
#  'zuschlag2597.htm',
#  'zuschlag1920.htm',
#  'zuschlag1277.htm',
#  'zuschlag2018.htm',
#  'zuschlag1511.htm',
#  'zuschlag385.htm',
#  'zuschlag1505.htm',
#  'zuschlag391.htm',
#  'zuschlag1263.htm',
#  'zuschlag2742.htm',
#  'zuschlag2024.htm',
#  'zuschlag2030.htm',
#  'zuschlag1539.htm',
#  'zuschlag2756.htm',
#  'zuschlag2965.htm',
#  'zuschlag420.htm',
#  'zuschlag346.htm',
#  'zuschlag352.htm',
#  'zuschlag434.htm',
#  'zuschlag2971.htm',
#  'zuschlag1288.htm',
#  'zuschlag2959.htm',
#  'zuschlag2781.htm',
#  'zuschlag2795.htm',
#  'zuschlag408.htm',
#  'zuschlag1303.htm',
#  'zuschlag597.htm',
#  'zuschlag1465.htm',
#  'zuschlag1471.htm',
#  'zuschlag2178.htm',
#  'zuschlag1317.htm',
#  'zuschlag583.htm',
#  'zuschlag2636.htm',
#  'zuschlag1459.htm',
#  'zuschlag2150.htm',
#  'zuschlag2144.htm',
#  'zuschlag99.htm',
#  'zuschlag2622.htm',
#  'zuschlag2811.htm',
#  'zuschlag72.htm',
#  'zuschlag554.htm',
#  'zuschlag232.htm',
#  'zuschlag226.htm',
#  'zuschlag540.htm',
#  'zuschlag66.htm',
#  'zuschlag2805.htm',
#  'zuschlag568.htm',
#  'zuschlag2193.htm',
#  'zuschlag2187.htm',
#  'zuschlag2839.htm',
#  'zuschlag1667.htm',
#  'zuschlag3070.htm',
#  'zuschlag2408.htm',
#  'zuschlag795.htm',
#  'zuschlag1101.htm',
#  'zuschlag781.htm',
#  'zuschlag1115.htm',
#  'zuschlag959.htm',
#  'zuschlag3064.htm',
#  'zuschlag1673.htm',
#  'zuschlag2352.htm',
#  'zuschlag1883.htm',
#  'zuschlag971.htm',
#  'zuschlag2434.htm',
#  'zuschlag2420.htm',
#  'zuschlag1129.htm',
#  'zuschlag965.htm',
#  'zuschlag1897.htm',
#  'zuschlag3058.htm',
#  'zuschlag2346.htm',
#  'zuschlag756.htm',
#  'zuschlag742.htm',
#  'zuschlag1868.htm',
#  'zuschlag1840.htm',
#  'zuschlag1698.htm',
#  'zuschlag2391.htm',
#  'zuschlag2385.htm',
#  'zuschlag1854.htm',
#  'zuschlag746.htm',
#  'zuschlag752.htm',
#  'zuschlag1878.htm',
#  'zuschlag1688.htm',
#  'zuschlag1850.htm',
#  'zuschlag2381.htm',
#  'zuschlag2395.htm',
#  'zuschlag1844.htm',
#  'zuschlag1677.htm',
#  'zuschlag3060.htm',
#  'zuschlag2418.htm',
#  'zuschlag1111.htm',
#  'zuschlag785.htm',
#  'zuschlag1105.htm',
#  'zuschlag949.htm',
#  'zuschlag791.htm',
#  'zuschlag3074.htm',
#  'zuschlag1663.htm',
#  'zuschlag2342.htm',
#  'zuschlag1893.htm',
#  'zuschlag961.htm',
#  'zuschlag2424.htm',
#  'zuschlag2430.htm',
#  'zuschlag1139.htm',
#  'zuschlag975.htm',
#  'zuschlag1887.htm',
#  'zuschlag2356.htm',
#  'zuschlag3048.htm',
#  'zuschlag2801.htm',
#  'zuschlag62.htm',
#  'zuschlag544.htm',
#  'zuschlag222.htm',
#  'zuschlag236.htm',
#  'zuschlag550.htm',
#  'zuschlag76.htm',
#  'zuschlag2815.htm',
#  'zuschlag578.htm',
#  'zuschlag2183.htm',
#  'zuschlag2197.htm',
#  'zuschlag2829.htm',
#  'zuschlag587.htm',
#  'zuschlag1313.htm',
#  'zuschlag1475.htm',
#  'zuschlag1461.htm',
#  'zuschlag2168.htm',
#  'zuschlag593.htm',
#  'zuschlag1307.htm',
#  'zuschlag2626.htm',
#  'zuschlag1449.htm',
#  'zuschlag2140.htm',
#  'zuschlag2154.htm',
#  'zuschlag89.htm',
#  'zuschlag2632.htm',
#  'zuschlag2975.htm',
#  'zuschlag430.htm',
#  'zuschlag356.htm',
#  'zuschlag342.htm',
#  'zuschlag424.htm',
#  'zuschlag2961.htm',
#  'zuschlag1298.htm',
#  'zuschlag2791.htm',
#  'zuschlag2949.htm',
#  'zuschlag2785.htm',
#  'zuschlag418.htm',
#  'zuschlag1267.htm',
#  'zuschlag2008.htm',
#  'zuschlag395.htm',
#  'zuschlag1501.htm',
#  'zuschlag381.htm',
#  'zuschlag1515.htm',
#  'zuschlag1273.htm',
#  'zuschlag2752.htm',
#  'zuschlag2034.htm',
#  'zuschlag2020.htm',
#  'zuschlag1529.htm',
#  'zuschlag2746.htm',
#  'zuschlag1918.htm',
#  'zuschlag154.htm',
#  'zuschlag632.htm',
#  '.DS_Store',
#  'zuschlag626.htm',
#  'zuschlag140.htm',
#  'zuschlag1924.htm',
#  'zuschlag168.htm',
#  'zuschlag2593.htm',
#  'zuschlag2587.htm',
#  'zuschlag1930.htm',
#  'zuschlag1703.htm',
#  'zuschlag197.htm',
#  'zuschlag3114.htm',
#  'zuschlag829.htm',
#  'zuschlag1065.htm',
#  'zuschlag1071.htm',
#  'zuschlag2578.htm',
#  'zuschlag3100.htm',
#  'zuschlag1717.htm',
#  'zuschlag183.htm',
#  'zuschlag3128.htm',
#  'zuschlag2236.htm',
#  'zuschlag815.htm',
#  'zuschlag1059.htm',
#  'zuschlag2550.htm',
#  'zuschlag2544.htm',
#  'zuschlag801.htm',
#  'zuschlag2222.htm',
#  'zuschlag800.htm',
#  'zuschlag2545.htm',
#  'zuschlag2223.htm',
#  'zuschlag2237.htm',
#  'zuschlag3129.htm',
#  'zuschlag2551.htm',
#  'zuschlag1058.htm',
#  'zuschlag814.htm',
#  'zuschlag2579.htm',
#  'zuschlag1070.htm',
#  'zuschlag182.htm',
#  'zuschlag1716.htm',
#  'zuschlag3101.htm',
#  'zuschlag3115.htm',
#  'zuschlag196.htm',
#  'zuschlag1702.htm',
#  'zuschlag1064.htm',
#  'zuschlag828.htm',
#  'zuschlag2586.htm',
#  'zuschlag1931.htm',
#  'zuschlag169.htm',
#  'zuschlag1925.htm',
#  'zuschlag2592.htm',
#  'zuschlag627.htm',
#  'zuschlag141.htm',
#  'zuschlag155.htm',
#  'zuschlag1919.htm',
#  'zuschlag633.htm',
#  'zuschlag1528.htm',
#  'zuschlag2021.htm',
#  'zuschlag2747.htm',
#  'zuschlag2753.htm',
#  'zuschlag2035.htm',
#  'zuschlag1514.htm',
#  'zuschlag380.htm',
#  'zuschlag1272.htm',
#  'zuschlag1266.htm',
#  'zuschlag1500.htm',
#  'zuschlag394.htm',
#  'zuschlag2009.htm',
#  'zuschlag419.htm',
#  'zuschlag2784.htm',
#  'zuschlag2948.htm',
#  'zuschlag2790.htm',
#  'zuschlag1299.htm',
#  'zuschlag343.htm',
#  'zuschlag2960.htm',
#  'zuschlag425.htm',
#  'zuschlag431.htm',
#  'zuschlag2974.htm',
#  'zuschlag357.htm',
#  'zuschlag2155.htm',
#  'zuschlag2633.htm',
#  'zuschlag88.htm',
#  'zuschlag2627.htm',
#  'zuschlag2141.htm',
#  'zuschlag1448.htm',
#  'zuschlag2169.htm',
#  'zuschlag1460.htm',
#  'zuschlag1306.htm',
#  'zuschlag592.htm',
#  'zuschlag1312.htm',
#  'zuschlag586.htm',
#  'zuschlag1474.htm',
#  'zuschlag2196.htm',
#  'zuschlag2828.htm',
#  'zuschlag579.htm',
#  'zuschlag2182.htm',
#  'zuschlag237.htm',
#  'zuschlag2814.htm',
#  'zuschlag77.htm',
#  'zuschlag551.htm',
#  'zuschlag545.htm',
#  'zuschlag63.htm',
#  'zuschlag2800.htm',
#  'zuschlag223.htm',
#  'zuschlag974.htm',
#  'zuschlag1138.htm',
#  'zuschlag2431.htm',
#  'zuschlag3049.htm',
#  'zuschlag2357.htm',
#  'zuschlag1886.htm',
#  'zuschlag1892.htm',
#  'zuschlag2343.htm',
#  'zuschlag2425.htm',
#  'zuschlag960.htm',
#  'zuschlag790.htm',
#  'zuschlag948.htm',
#  'zuschlag1104.htm',
#  'zuschlag1662.htm',
#  'zuschlag3075.htm',
#  'zuschlag3061.htm',
#  'zuschlag1676.htm',
#  'zuschlag784.htm',
#  'zuschlag1110.htm',
#  'zuschlag2419.htm',
#  'zuschlag1845.htm',
#  'zuschlag2394.htm',
#  'zuschlag2380.htm',
#  'zuschlag1851.htm',
#  'zuschlag1689.htm',
#  'zuschlag753.htm',
#  'zuschlag1879.htm',
#  'zuschlag747.htm',
#  'zuschlag751.htm',
#  'zuschlag989.htm',
#  'zuschlag745.htm',
#  'zuschlag3088.htm',
#  'zuschlag2396.htm',
#  'zuschlag1847.htm',
#  'zuschlag779.htm',
#  'zuschlag1853.htm',
#  'zuschlag2382.htm',
#  'zuschlag2369.htm',
#  'zuschlag3077.htm',
#  'zuschlag1660.htm',
#  'zuschlag1106.htm',
#  'zuschlag792.htm',
#  'zuschlag1112.htm',
#  'zuschlag786.htm',
#  'zuschlag1674.htm',
#  'zuschlag3063.htm',
#  'zuschlag1884.htm',
#  'zuschlag2355.htm',
#  'zuschlag2433.htm',
#  'zuschlag976.htm',
#  'zuschlag962.htm',
#  'zuschlag2427.htm',
#  'zuschlag2341.htm',
#  'zuschlag1890.htm',
#  'zuschlag1648.htm',
#  'zuschlag553.htm',
#  'zuschlag75.htm',
#  'zuschlag2816.htm',
#  'zuschlag235.htm',
#  'zuschlag221.htm',
#  'zuschlag2802.htm',
#  'zuschlag61.htm',
#  'zuschlag547.htm',
#  'zuschlag49.htm',
#  'zuschlag209.htm',
#  'zuschlag2194.htm',
#  'zuschlag2180.htm',
#  'zuschlag1489.htm',
#  'zuschlag590.htm',
#  'zuschlag1304.htm',
#  'zuschlag1462.htm',
#  'zuschlag1476.htm',
#  'zuschlag584.htm',
#  'zuschlag1310.htm',
#  'zuschlag2619.htm',
#  'zuschlag1338.htm',
#  'zuschlag2631.htm',
#  'zuschlag2157.htm',
#  'zuschlag2143.htm',
#  'zuschlag2625.htm',
#  'zuschlag427.htm',
#  'zuschlag2962.htm',
#  'zuschlag341.htm',
#  'zuschlag355.htm',
#  'zuschlag2976.htm',
#  'zuschlag433.htm',
#  'zuschlag2786.htm',
#  'zuschlag369.htm',
#  'zuschlag2792.htm',
#  'zuschlag2779.htm',
#  'zuschlag1270.htm',
#  'zuschlag382.htm',
#  'zuschlag1516.htm',
#  'zuschlag396.htm',
#  'zuschlag1502.htm',
#  'zuschlag1264.htm',
#  'zuschlag2745.htm',
#  'zuschlag2023.htm',
#  'zuschlag2037.htm',
#  'zuschlag2989.htm',
#  'zuschlag2751.htm',
#  'zuschlag1258.htm',
#  'zuschlag143.htm',
#  'zuschlag625.htm',
#  'zuschlag631.htm',
#  'zuschlag157.htm',
#  'zuschlag1933.htm',
#  'zuschlag619.htm',
#  'zuschlag2584.htm',
#  'zuschlag2590.htm',
#  'zuschlag1099.htm',
#  'zuschlag1927.htm',
#  'zuschlag3103.htm',
#  'zuschlag1714.htm',
#  'zuschlag180.htm',
#  'zuschlag1072.htm',
#  'zuschlag1066.htm',
#  'zuschlag1700.htm',
#  'zuschlag194.htm',
#  'zuschlag3117.htm',
#  'zuschlag2209.htm',
#  'zuschlag1728.htm',
#  'zuschlag2221.htm',
#  'zuschlag2547.htm',
#  'zuschlag802.htm',
#  'zuschlag816.htm',
#  'zuschlag2553.htm',
#  'zuschlag2235.htm',
#  'zuschlag2552.htm',
#  'zuschlag817.htm',
#  'zuschlag2234.htm',
#  'zuschlag2220.htm',
#  'zuschlag1729.htm',
#  'zuschlag803.htm',
#  'zuschlag2546.htm',
#  'zuschlag1067.htm',
#  'zuschlag2208.htm',
#  'zuschlag3116.htm',
#  'zuschlag195.htm',
#  'zuschlag1701.htm',
#  'zuschlag181.htm',
#  'zuschlag1715.htm',
#  'zuschlag3102.htm',
#  'zuschlag1073.htm',
#  'zuschlag1098.htm',
#  'zuschlag2591.htm',
#  'zuschlag1926.htm',
#  'zuschlag1932.htm',
#  'zuschlag2585.htm',
#  'zuschlag618.htm',
#  'zuschlag630.htm',
#  'zuschlag156.htm',
#  'zuschlag142.htm',
#  'zuschlag624.htm',
#  'zuschlag2036.htm',
#  'zuschlag1259.htm',
#  'zuschlag2750.htm',
#  'zuschlag2988.htm',
#  'zuschlag2744.htm',
#  'zuschlag2022.htm',
#  'zuschlag1503.htm',
#  'zuschlag397.htm',
#  'zuschlag1265.htm',
#  'zuschlag1271.htm',
#  'zuschlag2778.htm',
#  'zuschlag1517.htm',
#  'zuschlag383.htm',
#  'zuschlag368.htm',
#  'zuschlag2793.htm',
#  'zuschlag2787.htm',
#  'zuschlag354.htm',
#  'zuschlag432.htm',
#  'zuschlag2977.htm',
#  'zuschlag2963.htm',
#  'zuschlag426.htm',
#  'zuschlag340.htm',
#  'zuschlag2142.htm',
#  'zuschlag2624.htm',
#  'zuschlag2630.htm',
#  'zuschlag1339.htm',
#  'zuschlag2156.htm',
#  'zuschlag1477.htm',
#  'zuschlag2618.htm',
#  'zuschlag1311.htm',
#  'zuschlag585.htm',
#  'zuschlag1305.htm',
#  'zuschlag591.htm',
#  'zuschlag1463.htm',
#  'zuschlag1488.htm',
#  'zuschlag2181.htm',
#  'zuschlag48.htm',
#  'zuschlag2195.htm',
#  'zuschlag208.htm',
#  'zuschlag220.htm',
#  'zuschlag546.htm',
#  'zuschlag60.htm',
#  'zuschlag2803.htm',
#  'zuschlag2817.htm',
#  'zuschlag74.htm',
#  'zuschlag552.htm',
#  'zuschlag234.htm',
#  'zuschlag2426.htm',
#  'zuschlag963.htm',
#  'zuschlag1649.htm',
#  'zuschlag1891.htm',
#  'zuschlag2340.htm',
#  'zuschlag2354.htm',
#  'zuschlag1885.htm',
#  'zuschlag977.htm',
#  'zuschlag2432.htm',
#  'zuschlag787.htm',
#  'zuschlag1113.htm',
#  'zuschlag3062.htm',
#  'zuschlag1675.htm',
#  'zuschlag1661.htm',
#  'zuschlag3076.htm',
#  'zuschlag2368.htm',
#  'zuschlag793.htm',
#  'zuschlag1107.htm',
#  'zuschlag778.htm',
#  'zuschlag2383.htm',
#  'zuschlag1852.htm',
#  'zuschlag1846.htm',
#  'zuschlag2397.htm',
#  'zuschlag3089.htm',
#  'zuschlag744.htm',
#  'zuschlag988.htm',
#  'zuschlag750.htm',
#  'zuschlag1821.htm',
#  'zuschlag2496.htm',
#  'zuschlag2482.htm',
#  'zuschlag1835.htm',
#  'zuschlag737.htm',
#  'zuschlag723.htm',
#  'zuschlag1809.htm',
#  'zuschlag2333.htm',
#  'zuschlag910.htm',
#  'zuschlag2455.htm',
#  'zuschlag2441.htm',
#  'zuschlag904.htm',
#  'zuschlag1148.htm',
#  'zuschlag2327.htm',
#  'zuschlag3039.htm',
#  'zuschlag1606.htm',
#  'zuschlag3011.htm',
#  'zuschlag2469.htm',
#  'zuschlag1160.htm',
#  'zuschlag938.htm',
#  'zuschlag1174.htm',
#  'zuschlag3005.htm',
#  'zuschlag1612.htm',
#  'zuschlag509.htm',
#  'zuschlag2694.htm',
#  'zuschlag2858.htm',
#  'zuschlag2680.htm',
#  'zuschlag1389.htm',
#  'zuschlag2870.htm',
#  'zuschlag13.htm',
#  'zuschlag535.htm',
#  'zuschlag253.htm',
#  'zuschlag247.htm',
#  'zuschlag521.htm',
#  'zuschlag2864.htm',
#  'zuschlag2657.htm',
#  'zuschlag1438.htm',
#  'zuschlag2131.htm',
#  'zuschlag2125.htm',
#  'zuschlag3.htm',
#  'zuschlag2643.htm',
#  'zuschlag1362.htm',
#  'zuschlag1404.htm',
#  'zuschlag290.htm',
#  'zuschlag1410.htm',
#  'zuschlag284.htm',
#  'zuschlag2119.htm',
#  'zuschlag1376.htm',
#  'zuschlag2938.htm',
#  'zuschlag2086.htm',
#  'zuschlag2092.htm',
#  'zuschlag469.htm',
#  'zuschlag2904.htm',
#  'zuschlag441.htm',
#  'zuschlag327.htm',
#  'zuschlag333.htm',
#  'zuschlag455.htm',
#  'zuschlag2910.htm',
#  'zuschlag2723.htm',
#  'zuschlag2045.htm',
#  'zuschlag2051.htm',
#  'zuschlag1558.htm',
#  'zuschlag2737.htm',
#  'zuschlag1216.htm',
#  'zuschlag482.htm',
#  'zuschlag2079.htm',
#  'zuschlag1570.htm',
#  'zuschlag1564.htm',
#  'zuschlag1202.htm',
#  'zuschlag496.htm',
#  'zuschlag119.htm',
#  'zuschlag1955.htm',
#  'zuschlag2284.htm',
#  'zuschlag2290.htm',
#  'zuschlag1941.htm',
#  'zuschlag1799.htm',
#  'zuschlag125.htm',
#  'zuschlag1969.htm',
#  'zuschlag643.htm',
#  'zuschlag657.htm',
#  'zuschlag131.htm',
#  'zuschlag2247.htm',
#  'zuschlag1996.htm',
#  'zuschlag1028.htm',
#  'zuschlag864.htm',
#  'zuschlag2521.htm',
#  'zuschlag2535.htm',
#  'zuschlag870.htm',
#  'zuschlag1982.htm',
#  'zuschlag2253.htm',
#  'zuschlag1772.htm',
#  'zuschlag680.htm',
#  'zuschlag1014.htm',
#  'zuschlag858.htm',
#  'zuschlag694.htm',
#  'zuschlag1000.htm',
#  'zuschlag2509.htm',
#  'zuschlag1766.htm',
#  'zuschlag2508.htm',
#  'zuschlag1001.htm',
#  'zuschlag695.htm',
#  'zuschlag1767.htm',
#  'zuschlag1773.htm',
#  'zuschlag859.htm',
#  'zuschlag1015.htm',
#  'zuschlag681.htm',
#  'zuschlag871.htm',
#  'zuschlag2534.htm',
#  'zuschlag2252.htm',
#  'zuschlag1983.htm',
#  'zuschlag1997.htm',
#  'zuschlag2246.htm',
#  'zuschlag2520.htm',
#  'zuschlag865.htm',
#  'zuschlag1029.htm',
#  'zuschlag656.htm',
#  'zuschlag130.htm',
#  'zuschlag1968.htm',
#  'zuschlag124.htm',
#  'zuschlag642.htm',
#  'zuschlag1798.htm',
#  'zuschlag1940.htm',
#  'zuschlag2291.htm',
#  'zuschlag2285.htm',
#  'zuschlag1954.htm',
#  'zuschlag118.htm',
#  'zuschlag1565.htm',
#  'zuschlag497.htm',
#  'zuschlag1203.htm',
#  'zuschlag483.htm',
#  'zuschlag1217.htm',
#  'zuschlag1571.htm',
#  'zuschlag2078.htm',
#  'zuschlag1559.htm',
#  'zuschlag2050.htm',
#  'zuschlag2736.htm',
#  'zuschlag2722.htm',
#  'zuschlag2044.htm',
#  'zuschlag332.htm',
#  'zuschlag2911.htm',
#  'zuschlag454.htm',
#  'zuschlag440.htm',
#  'zuschlag2905.htm',
#  'zuschlag326.htm',
#  'zuschlag2093.htm',
#  'zuschlag468.htm',
#  'zuschlag2939.htm',
#  'zuschlag2087.htm',
#  'zuschlag2118.htm',
#  'zuschlag285.htm',
#  'zuschlag1411.htm',
#  'zuschlag1377.htm',
#  'zuschlag1363.htm',
#  'zuschlag291.htm',
#  'zuschlag1405.htm',
#  'zuschlag2124.htm',
#  'zuschlag2642.htm',
#  'zuschlag2.htm',
#  'zuschlag2656.htm',
#  'zuschlag2130.htm',
#  'zuschlag1439.htm',
#  'zuschlag246.htm',
#  'zuschlag2865.htm',
#  'zuschlag520.htm',
#  'zuschlag534.htm',
#  'zuschlag12.htm',
#  'zuschlag2871.htm',
#  'zuschlag252.htm',
#  'zuschlag1388.htm',
#  'zuschlag2681.htm',
#  'zuschlag2859.htm',
#  'zuschlag2695.htm',
#  'zuschlag508.htm',
#  'zuschlag1175.htm',
#  'zuschlag939.htm',
#  'zuschlag1613.htm',
#  'zuschlag3004.htm',
#  'zuschlag3010.htm',
#  'zuschlag1607.htm',
#  'zuschlag1161.htm',
#  'zuschlag2468.htm',
#  'zuschlag1149.htm',
#  'zuschlag905.htm',
#  ...]
