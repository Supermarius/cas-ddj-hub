# %% [markdown]
# hier als file einfach das gewünschte File eingeben: parteiübergreifend/blockübergreifend/linksübergreifend

# %%
import warnings
warnings.filterwarnings('ignore')

import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd

file = open("Dataframe_bereinigt_linksuebergreifend.csv", mode="r")
df2= pd.read_csv(file)
df2 = df2.set_index("Unnamed: 0")

# %% [markdown]
# Problem bei Datierung: Ein paar Geschäfte (die mit anderen verknüpft sind) haben ein fehlerhaftes Datum ("08.01.20"), das die to_datetime-Kovertierung stört. Diese erseten wird mit dem Wert 31.12. plus dem entsprechenden Wert aus dem Geschäft. Das machen wir so:

# %%
fehlerposition3 = df2[df2["Datum"] == "08.01.20"].index.tolist()

for zeile in fehlerposition3:
    Jahr = df2.loc[zeile, "Geschäft"].split("/")[0]
    Ersatzdatum = "31.12." + Jahr
    df2.loc[zeile, "Datum"] = df2.loc[zeile, "Datum"].replace("08.01.20", Ersatzdatum)

# %% [markdown]
# Bei den Parteiübergreifenden hats noch zwei Spezialfälle drin, die ich manuell korrigiere:

# %%
df2.loc[61, "Datum"] = df2.loc[zeile, "Datum"].replace("30.1.91", "30.1.1991")
df2.loc[612, "Datum"] = df2.loc[zeile, "Datum"].replace("18.12.19", "30.05.2001")

# %% [markdown]
# Bei den Blockübergreifenden hats hier einen Spezialfall drin, die ich manuell korrigiere:

# %%
df2.loc[110, "Datum"] = df2.loc[zeile, "Datum"].replace("30.6.", "30.6.2004")#

# %% [markdown]
# Jetzt gehts endlich!

# %%
df2["Datum"] = pd.to_datetime(df2['Datum'], format='%d.%m.%Y')

# %%
df2.head(5)
# Out:
#                 Datum  Geschäft  Einreichender 1 Partei 1 Block 1  \
# Unnamed: 0
# 0          2013-05-16  2005/550    Mario Mariani      CVP   mitte
# 1          2004-12-01  2004/637     Corine Mauch       SP   links
# 2          2018-09-19  2018/361  Matthias Probst    Grüne   links
# 3          2004-04-07  2004/192     Daniel Leupi    Grüne   links
# 4          2017-07-12  2017/247  Ursula Uttinger      FDP  rechts
#
#              Einreichender 2 Partei 2 Block 2  \
# Unnamed: 0
# 0              Muriel Herzig    Grüne   links
# 1              Albert Leiser      FDP  rechts
# 2                 Guido Hüni      GLP   mitte
# 3           Christian Traber      CVP   mitte
# 4               Marco Denoth       SP   links
#
#                                           Departement
# Unnamed: 0
# 0                                                 NaN
# 1                                                 NaN
# 2                                            Stadtrat
# 3           Tiefbau- und Entsorgungsdepartement (TED)
# 4                                            Stadtrat

# %% [markdown]
# Damit können wir jetzt mit dem Timestamp nach Legislaturen filtern (zumindest Annäherungsweise: Wechsel = Mitte Mai)

# %%
df2 = df2.set_index("Datum")

# %%
df2.head(25)
# Out:
#             Geschäft      Einreichender 1 Partei 1 Block 1  \
# Datum
# 2013-05-16  2005/550        Mario Mariani      CVP   mitte
# 2004-12-01  2004/637         Corine Mauch       SP   links
# 2018-09-19  2018/361      Matthias Probst    Grüne   links
# 2004-04-07  2004/192         Daniel Leupi    Grüne   links
# 2017-07-12  2017/247      Ursula Uttinger      FDP  rechts
# 2019-01-30   2019/46       Markus Baumann      GLP   mitte
# 2019-03-13   2019/91       Balz Bürgisser    Grüne   links
# 2016-07-06  2016/257        Jonas Steiner       SP   links
# 2014-06-11  2014/187           Peter Küng       SP   links
# 2006-06-21  2006/257         Heinz Jacobi       SP   links
# 2005-06-22  2003/306  Robert Schönbächler      CVP   mitte
# 2009-12-16  2009/601         Bruno Wohler      SVP  rechts
# 2009-09-30  2007/642         Daniel Leupi    Grüne   links
# 2011-05-18  2005/551      Bernhard Piller    Grüne   links
# 2005-02-08  2005/223         Corine Mauch       SP   links
# 2006-05-03  2006/135        Judith Bucher       SP   links
# 2004-11-10  2004/583     Thomas Marthaler       SP   links
# 2016-04-20  2016/135     Pascal Lamprecht       SP   links
# 2014-12-31  2014/230  Marcel Schönbächler      CVP   mitte
# 2009-11-25  2009/549         Walter Angst       AL   links
# 2011-09-21  2011/349        Dorothea Frei       SP   links
# 2015-02-04   2015/44        Markus Knauss    Grüne   links
# 2016-04-20  2016/137        Marcel Tobler       SP   links
# 2010-09-29  2010/416      Gabriele Kisker    Grüne   links
# 2005-02-09   2005/41  Robert Schönbächler      CVP   mitte
#
#                  Einreichender 2 Partei 2 Block 2  \
# Datum
# 2013-05-16         Muriel Herzig    Grüne   links
# 2004-12-01         Albert Leiser      FDP  rechts
# 2018-09-19            Guido Hüni      GLP   mitte
# 2004-04-07      Christian Traber      CVP   mitte
# 2017-07-12          Marco Denoth       SP   links
# 2019-01-30          Marco Denoth       SP   links
# 2019-03-13     Yasmine Bourgeois      FDP  rechts
# 2016-07-06       Ursula Uttinger      FDP  rechts
# 2014-06-11       Gian von Planta      GLP   mitte
# 2006-06-21   Robert Schönbächler      CVP   mitte
# 2005-06-22          Daniel Leupi    Grüne   links
# 2009-12-16           Thomas Wyss    Grüne   links
# 2009-09-30        Roger Tognella      FDP  rechts
# 2011-05-18         Mario Mariani      CVP   mitte
# 2005-02-08          Ernst Danner      EVP   mitte
# 2006-05-03      Christian Traber      CVP   mitte
# 2004-11-10      Christian Traber      CVP   mitte
# 2016-04-20        Markus Baumann      GLP   mitte
# 2014-12-31            Peter Küng       SP   links
# 2009-11-25  Jean-Claude Virchaux      CVP   mitte
# 2011-09-21        Roger Tognella      FDP  rechts
# 2015-02-04        Guido Trevisan      GLP   mitte
# 2016-04-20   Markus Hungerbühler      CVP   mitte
# 2010-09-29          Samuel Dubno      GLP   mitte
# 2005-02-09           Heinz Bögle       SP   links
#
#                                              Departement
# Datum
# 2013-05-16                                           NaN
# 2004-12-01                                           NaN
# 2018-09-19                                      Stadtrat
# 2004-04-07     Tiefbau- und Entsorgungsdepartement (TED)
# 2017-07-12                                      Stadtrat
# 2019-01-30                                   Gemeinderat
# 2019-03-13                                   Gemeinderat
# 2016-07-06                                      Stadtrat
# 2014-06-11     Tiefbau- und Entsorgungsdepartement (TED)
# 2006-06-21  Departement der Industriellen Betriebe (DIB)
# 2005-06-22                                           NaN
# 2009-12-16                      Hochbaudepartement (HBD)
# 2009-09-30                                           NaN
# 2011-05-18                                           NaN
# 2005-02-08                                           NaN
# 2006-05-03                                           NaN
# 2004-11-10                       Polizeidepartement (PD)
# 2016-04-20                                      Stadtrat
# 2014-12-31                                           NaN
# 2009-11-25                                           NaN
# 2011-09-21     Tiefbau- und Entsorgungsdepartement (TED)
# 2015-02-04                                           NaN
# 2016-04-20                                           NaN
# 2010-09-29     Tiefbau- und Entsorgungsdepartement (TED)
# 2005-02-09     Tiefbau- und Entsorgungsdepartement (TED)

# %%
#den ersten nehme ich raus, weil er leer ist > produziert fehler
#df_1990 = df2["1990-05-15":"1994-05-14"]
df_1994 = df2["1994-05-15":"1998-05-14"]
df_1998 = df2["1998-05-15":"2002-05-14"]
df_2002 = df2["2002-05-15":"2006-05-14"]
df_2006 = df2["2006-05-15":"2010-05-14"]
df_2010 = df2["2010-05-15":"2014-05-14"]
df_2014 = df2["2014-05-15":"2018-05-14"]
df_2018 = df2["2018-05-15":"2022-05-14"]

#das gleiche gilt hier:
dataframe_list = [df_1994, df_1998, df_2002, df_2006, df_2010, df_2014, df_2018]

# %%
df_2018.head(5)
# Out:
#             Geschäft  Einreichender 1 Partei 1 Block 1    Einreichender 2  \
# Datum
# 2018-09-19  2018/361  Matthias Probst    Grüne   links         Guido Hüni
# 2019-01-30   2019/46   Markus Baumann      GLP   mitte       Marco Denoth
# 2019-03-13   2019/91   Balz Bürgisser    Grüne   links  Yasmine Bourgeois
# 2019-01-09    2019/4    Marcel Müller      FDP  rechts   Pascal Lamprecht
# 2019-03-06   2019/82  Roger Bartholdi      SVP  rechts   Pascal Lamprecht
#
#            Partei 2 Block 2  Departement
# Datum
# 2018-09-19      GLP   mitte     Stadtrat
# 2019-01-30       SP   links  Gemeinderat
# 2019-03-13      FDP  rechts  Gemeinderat
# 2019-01-09       SP   links     Stadtrat
# 2019-03-06       SP   links     Stadtrat

# %% [markdown]
# ### Werten wir mal die Anzahl nach Legislatur aus:

# %%
dict_list = []
startjahr = 1994
for frame in dataframe_list:
    anzahl = (len(frame))
    mini_dict = {"Legislatur": str(startjahr)+" bis "+str(startjahr+4), "Geschäfte": anzahl}
    dict_list.append(mini_dict)
    startjahr += 4
    
df = pd.DataFrame(dict_list)
df
# Out:
#       Legislatur  Geschäfte
# 0  1994 bis 1998          7
# 1  1998 bis 2002         18
# 2  2002 bis 2006         58
# 3  2006 bis 2010         54
# 4  2010 bis 2014         52
# 5  2014 bis 2018         62
# 6  2018 bis 2022         53

# %% [markdown]
# ### Analyse einzelner Legislaturen nach Parteipaaren:

# %%
legislatur = input("Bitte Legislaturstart eingeben:")
# Out:
# Bitte Legislaturstart eingeben:2014

# %%
legislatur = int(legislatur)

if legislatur == 1994:
    frame = dataframe_list[0]
elif legislatur == 1998:
    frame = dataframe_list[1]
elif legislatur == 2002:
    frame = dataframe_list[2]
elif legislatur == 2006:
    frame = dataframe_list[3]
elif legislatur == 2010:
    frame = dataframe_list[4]
elif legislatur == 2014:
    frame = dataframe_list[5]
elif legislatur == 2018:
    frame = dataframe_list[6]
else: 
    print("ungültige Legislatur eingegeben!")

# %%
frame = frame.reset_index()

# %%
# Hier arbeiten wir mit dem ord-Befehl, der eine Zahl für die Anfangsbuchstaben der Parteien abfragt, um alle Paare nur einmal zu erfassen:
for element in range(0, len(frame)-1):
    if ord(frame.loc[element,"Partei 1"][0]) < ord(frame.loc[element,"Partei 2"][0]):
        frame.loc[element, "Parteipaar"] = frame.loc[element,"Partei 1"] + " / "+ frame.loc[element,"Partei 2"]
    elif ord(frame.loc[element,"Partei 1"][0]) > ord(frame.loc[element,"Partei 2"][0]):
        frame.loc[element, "Parteipaar"] = frame.loc[element,"Partei 2"] + " / "+ frame.loc[element,"Partei 1"]
    else:
        if ord(frame.loc[element,"Partei 1"][1]) < ord(frame.loc[element,"Partei 2"][1]):
            frame.loc[element, "Parteipaar"] = frame.loc[element,"Partei 1"] + " / "+ frame.loc[element,"Partei 2"]
        else:
            frame.loc[element, "Parteipaar"] = frame.loc[element,"Partei 2"] + " / "+ frame.loc[element,"Partei 1"]

# %%
frame["Parteipaar"].value_counts().to_frame()
# Out:
#                 Parteipaar
# GLP / SP                19
# GLP / Grüne             12
# CVP / SP                11
# FDP / SP                 7
# FDP / GLP                6
# CVP / FDP                6
# AL / GLP                 5
# CVP / SVP                3
# CVP / Grüne              2
# AL / FDP                 2
# SP / SVP                 1
# AL / Parteilos           1
# Grüne / SVP              1

# %% [markdown]
# ### Netzwerk-Export für Gephi

# %% [markdown]
# Weil wirs nicht geschafft haben, in Gephi dynamische Graphs mit Timestamps zu machen, bauen wir jetzt einen Loop, der uns für jede Legislatur ein separates gefx-File baut:

# %%
for frame in dataframe_list:
    #müssen neuen Index machen, sonst kann man die einzelnen locs nicht ansteuern...
    frame.reset_index(inplace = True)
    Netz = nx.Graph()

    for a in range(0,(len(frame)-1)):
        Person1 = str(frame.loc[a]["Einreichender 1"])
        Person2 = str(frame.loc[a]["Einreichender 2"])
        Partei1 = str(frame.loc[a]["Partei 1"])
        Partei2 = str(frame.loc[a]["Partei 2"])
        Netz.add_node(Person1, Partei = Partei1)
        Netz.add_node(Person2, Partei = Partei2)

    #Als zweites machen wir die edges und versehen sie mit eindem datetime-Datum:
    for a in range(0,(len(frame)-1)):
        Person1 = str(frame.loc[a]["Einreichender 1"])
        Person2 = str(frame.loc[a]["Einreichender 2"])
        date = str(frame.loc[a]["Datum"])
        Departement = str(frame.loc[a]["Departement"])
    
        #Beziehungen, die mehrmals vorkommen, sollte gewichtet werden (weight +1)
        if Netz.has_edge(Person1, Person2):
            Netz[Person1][Person2]["weight"] += 1
        else:
            Netz.add_edge(Person1, Person2, datum = date, thema = Departement, weight=1)
    
    nx.write_gexf(Netz, "Paare_"+str(frame.loc[0]["Geschäft"].split("/")[0])+".gexf")

# %% [markdown]
# ### Netzwerkanalyse einzelner Legislaturen:

# %%
legislatur = input("Bitte Legislaturstart eingeben:")
# Out:
# Bitte Legislaturstart eingeben:2006

# %%
legislatur = int(legislatur)

if legislatur == 1994:
    frame = dataframe_list[0]
elif legislatur == 1998:
    frame = dataframe_list[1]
elif legislatur == 2002:
    frame = dataframe_list[2]
elif legislatur == 2006:
    frame = dataframe_list[3]
elif legislatur == 2010:
    frame = dataframe_list[4]
elif legislatur == 2014:
    frame = dataframe_list[5]
elif legislatur == 2018:
    frame = dataframe_list[6]
else: 
    print("ungültige Legislatur eingegeben!")

# %%
#NetworkX nochmals bauen:
Netz = nx.Graph()

frame.reset_index(inplace = True)

for a in range(0,(len(frame)-1)):
    Person1 = str(frame.loc[a]["Einreichender 1"])
    Person2 = str(frame.loc[a]["Einreichender 2"])
    Partei1 = str(frame.loc[a]["Partei 1"])
    Partei2 = str(frame.loc[a]["Partei 2"])
    Netz.add_node(Person1, Partei = Partei1)
    Netz.add_node(Person2, Partei = Partei2)

    #Als zweites machen wir die edges und versehen sie mit eindem datetime-Datum:
for a in range(0,(len(frame)-1)):
    Person1 = str(frame.loc[a]["Einreichender 1"])
    Person2 = str(frame.loc[a]["Einreichender 2"])
    date = str(frame.loc[a]["Datum"])
    Departement = str(frame.loc[a]["Departement"])
    
    #Beziehungen, die mehrmals vorkommen, sollte gewichtet werden (weight +1)
    if Netz.has_edge(Person1, Person2):
        Netz[Person1][Person2]["weight"] += 1
    else:
        Netz.add_edge(Person1, Person2, datum = date, thema = Departement, weight=1)

# %% [markdown]
# Und jetzt zur Analyse:

# %%
#generelle Infos zum aktuellen Netz
print(nx.info(Netz))
# Out:
# Name:
# Type: Graph
# Number of nodes: 72
# Number of edges: 75
# Average degree:   2.0833

# %% [markdown]
# **degree** = Anzahl der Kanten die mit dem Knoten verbunden sind<br>
# **gewichteter degree** = summe der gewichteten Kanten

# %%
wdegree = dict(Netz.degree(weight='weight'))
#wdegree

#So bekommen wir de Leader zu diesem Wert
max(Netz, key=wdegree.get)
# Out:
# 'Monika Bloch Süss'

# %% [markdown]
# **degree centrality** = Wieviele Kanten hat ein Knoten prozentual gemessen am möglichen Maxmimum?<br>
# (gemessen an diesem Netz von Leuten, die über partei- oder blockgrenzen miteinander im Austausch stehen.)

# %%
degc = nx.degree_centrality(Netz)
#sorted(degc.items(), key=itemgetter(1), reverse=True)

# %% [markdown]
# **betweenness centrality** =  Summe der Anteile aller kürzesten Pfade von x nach y, die durch diesen Knoten laufen

# %%
from operator import itemgetter

#Knoten die mehrere Personen verbinden, oder oft dazwischen liegen haben eine hohe Betweenness.
bet = nx.betweenness_centrality(Netz)
#sorted(bet.items(), key=itemgetter(1), reverse=True)

# %% [markdown]
# **closeness centrality** = summe der kürzesten Pfade vom Knoten zu allen anderen Knoten

# %%
clos = nx.closeness_centrality(Netz)
#sorted(clos.items(), key=itemgetter(1), reverse=True)

# %% [markdown]
# **eigenvector centrality** = gewichtet Knoten basierend auf der Idee, dass Knoten mit hohen Gewichten mehr zur Zentrelität beitragen als Knoten mit niedrigen Gewichten. (Wer mit wichtigen Leuten verbunden ist, ist selbst wichtiger)

# %%
eig = nx.eigenvector_centrality(Netz)
#sorted(eig.items(), key=itemgetter(1), reverse=True)
# Out:
# ---------------------------------------------------------------------------
# PowerIterationFailedConvergence           Traceback (most recent call last)
# <ipython-input-771-a5592dc6dd30> in <module>
# ----> 1 eig = nx.eigenvector_centrality(Netz)
#       2 #sorted(eig.items(), key=itemgetter(1), reverse=True)
#
# </Users/bigdata/.virtualenvs/erstesVE/lib/python3.7/site-packages/decorator.py:decorator-gen-285> in eigenvector_centrality(G, max_iter, tol, nstart, weight)
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/networkx/utils/decorators.py in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      80             raise nx.NetworkXNotImplemented(msg)
#      81         else:
# ---> 82             return not_implement_for_func(*args, **kwargs)
#      83     return _not_implemented_for
#      84
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/networkx/algorithms/centrality/eigenvector.py in eigenvector_centrality(G, max_iter, tol, nstart, weight)
#     147         if sum(abs(x[n] - xlast[n]) for n in x) < nnodes * tol:
#     148             return x
# --> 149     raise nx.PowerIterationFailedConvergence(max_iter)
#     150
#     151
#
# PowerIterationFailedConvergence: (PowerIterationFailedConvergence(...), 'power iteration failed to converge within 100 iterations')

# %% [markdown]
# Und hier die Übersicht:

# %%
centrality_measures = {
    'degree': degc,
    'betweenness': bet,
    'closeness': clos,
    #"eigenvector": eig,
}
centrality = pd.DataFrame(centrality_measures)
centrality.sort_values("betweenness", ascending = False).head(10)
# Out:
#                        degree  betweenness  closeness
# Ernst Danner         0.098592     0.343662   0.260187
# Monika Bloch Süss    0.126761     0.300000   0.239490
# Bernhard Piller      0.056338     0.256137   0.252901
# Mario Mariani        0.070423     0.212944   0.239490
# Robert Schönbächler  0.112676     0.206841   0.229077
# Myrtha Meuli         0.042254     0.197787   0.242243
# Pierino Cerliani     0.042254     0.170020   0.225001
# Josef Widler         0.056338     0.152046   0.231595
# Thomas Wyss          0.042254     0.135010   0.229910
# Bruno Wohler         0.028169     0.118712   0.225805
