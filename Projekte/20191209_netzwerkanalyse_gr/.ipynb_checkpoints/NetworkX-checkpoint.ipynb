# %%
import warnings
warnings.filterwarnings('ignore')

import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
print('NetworkX version: {}'.format(nx.__version__))
# Out:
# NetworkX version: 2.4

# %%
import pandas as pd

# %% [markdown]
# ### 1. Versuch

# %%
file = open("Dataframe_bereinigt_parteiuebergreifend.csv", mode="r")
df=pd.read_csv(file)
df.set_index("Unnamed: 0").head(5)
# Out:
#                  Datum  Geschäft     Einreichender 1 Partei 1  \
# Unnamed: 0
# 0           25.11.2009  2009/562          Kurt Hüssy      SVP
# 1            21.8.2002  2002/289       Markus Schwyn      PFZ
# 2             3.5.2006  2006/134  Richard Rabelbauer      EVP
# 3           26.05.2010   2008/16       Rebekka Wyler       SP
# 4            30.8.2000  2000/415       Markus Schwyn      PFZ
#
#                 Einreichender 2 Partei 2  \
# Unnamed: 0
# 0                Peter Anderegg      EVP
# 1                Monika Erfigen      SVP
# 2           Robert Schönbächler      CVP
# 3              Pierino Cerliani    Grüne
# 4                   Mauro Tuena      SVP
#
#                                              Departement
# Unnamed: 0
# 0                                Polizeidepartement (PD)
# 1                               Hochbaudepartement (HBD)
# 2           Departement der Industriellen Betriebe (DIB)
# 3                                                    NaN
# 4                                 Sozialdepartement (SD)

# %%
Netz = nx.Graph()

# %%
len(df)
# Out:
# 958

# %%
for a in range(0,(len(df)-1)):
    Punkt1 = str(df.loc[a]["Einreichender 1"] + ", " + df.loc[a]["Partei 1"])
    Punkt2 = str(df.loc[a]["Einreichender 2"] + ", " + df.loc[a]["Partei 2"])
    Netz.add_edge(Punkt1, Punkt2)

# %%
Netz

# %%
nx.draw(Netz, node_size=800, node_color='red', with_labels=True)

# %%
nx.write_gexf(Netz, "Politikerpaare.gexf")

# %% [markdown]
# ### Auswertungen

# %%
from operator import itemgetter

#Knoten die mehrere Personen verbinden, oder oft dazwischen liegen haben eine hohe Betweenness.
bet = nx.betweenness_centrality(Netz)
sorted(bet.items(), key=itemgetter(1), reverse=True)
# Out:
# [('Ernst Danner, EVP', 0.1265690978199915),
#  ('Robert Schönbächler, CVP', 0.10760665151189089),
#  ('Markus Schwyn, PFZ', 0.10402213803642062),
#  ('Markus Knauss, Grüne', 0.08159543790414375),
#  ('Susi Gut, PFZ', 0.08033354017306266),
#  ('Mario Mariani, CVP', 0.06679175201395808),
#  ('Monjek Rosenheim, FDP', 0.05500604750069403),
#  ('Ueli Nagel, Grüne', 0.05378565264550255),
#  ('Bernhard Piller, Grüne', 0.04762271963924746),
#  ('Jean-Daniel Strub, SP', 0.04562566217421133),
#  ('Christian Traber, CVP', 0.044430388121160916),
#  ('Daniel Leupi, Grüne', 0.04214028227360588),
#  ('Matthias Probst, Grüne', 0.04093460890096227),
#  ('Walter Angst, AL', 0.04043926037429228),
#  ('Balz Bürgisser, Grüne', 0.040320541810816485),
#  ('Niklaus Scherr, AL', 0.039377239697613316),
#  ('Albert Leiser, FDP', 0.03501454240256606),
#  ('Marco Denoth, SP', 0.033850422736983195),
#  ('Christine Seidler, SP', 0.03340686499510005),
#  ('Roger Tognella, FDP', 0.033265450677986814),
#  ('Isabel Garcia, GLP', 0.03299787908477723),
#  ('Balthasar Glättli, Grüne', 0.03290963535370541),
#  ('Roger Bartholdi, SVP', 0.03011434154121045),
#  ('Gerold Lauber, CVP', 0.02977124385646259),
#  ('Joe A. Manser, SP', 0.029181022527716614),
#  ('Katharina Prelicz-Huber, Grüne', 0.029169802097797286),
#  ('Ann-Catherine Nabholz, GLP', 0.028708942474313694),
#  ('Pierino Cerliani, Grüne', 0.02824980452389433),
#  ('Markus Baumann, GLP', 0.027278647517694193),
#  ('Bruno Garzotto, SVP', 0.02693628562357268),
#  ('Richard Rabelbauer, EVP', 0.026620255323918207),
#  ('Heinz F. Steger, FDP', 0.02654264929162361),
#  ('Pascal Lamprecht, SP', 0.02645612627850776),
#  ('Markus Merki, GLP', 0.026335591820142005),
#  ('Andreas J. Schlegel, FDP', 0.0260608431095146),
#  ('Peter Stähli-Barth, SP', 0.025887226462556784),
#  ('Claudia Nielsen, SP', 0.025539636750772098),
#  ('Gabriele Kisker, Grüne', 0.02531315710496681),
#  ('Gregor Bucher, Grüne', 0.023465703483785842),
#  ('Daniel Meier, CVP', 0.02287225507239829),
#  ('Dorothea Frei, SP', 0.02250006612794904),
#  ('Köbi Möri, Parteilos', 0.02247061133211978),
#  ('Willy Furter, EVP', 0.022038632220199014),
#  ('Hans Jörg Käppeli, SP', 0.021308787884122084),
#  ('Simone Brander, SP', 0.021028665501801526),
#  ('Alecs Recher, AL', 0.020701925768273382),
#  ('Roger Liebi, SVP', 0.0205483166327047),
#  ('Monika Bloch Süss, CSP', 0.01990619820645993),
#  ('Alan David Sangines, SP', 0.018859589213481888),
#  ('Markus Hungerbühler, CVP', 0.01864255270989575),
#  ('Michael Baumer, FDP', 0.01777629163090947),
#  ('Guido Trevisan, GLP', 0.017645683902530025),
#  ('Marlène Butz, SP', 0.01711230318498183),
#  ('Min Li Marti, SP', 0.016760707825282075),
#  ('Sven Sobernheim, GLP', 0.016082762729590947),
#  ('Alexander Jäger, FDP', 0.015779058476533023),
#  ('Marcel Bührig, Grüne', 0.01577167943300379),
#  ('Eduard Guggenheim, AL', 0.015673196696020915),
#  ('Christina Schiller, AL', 0.015419659575259497),
#  ('Samuel Dubno, GLP', 0.014850546714363538),
#  ('Rebekka Wyler, SP', 0.014718944124702805),
#  ('Ursula Uttinger, FDP', 0.01456248543038656),
#  ('Urs Rechsteiner, CVP', 0.01387894473259234),
#  ('Urs Helfenstein, SP', 0.013645373344973944),
#  ('Christoph Hug, Grüne', 0.01342602808068428),
#  ('Ruth Anhorn, SVP', 0.013342019064940727),
#  ('Georg Schmid, CVP', 0.013257499885592907),
#  ('Hans-Ulrich Meier, FDP', 0.012844729112445679),
#  ('Guido Hüni, GLP', 0.012830757699429122),
#  ('Theo Hauri, SVP', 0.012756132186094043),
#  ('Thomas Wyss, Grüne', 0.012568843948656708),
#  ('Bruno Wohler, SVP', 0.012203818492072336),
#  ('Hans Marolf, SVP', 0.011988074418973812),
#  ('Monika Erfigen, SVP', 0.011909705159849654),
#  ('Mauro Tuena, SVP', 0.011884200154957981),
#  ('Markus Bischoff, AL', 0.011815686382078496),
#  ('Peider Filli, Grüne', 0.011423589034444785),
#  ('Marion Schmid, SP', 0.011386801397643672),
#  ('Anjushka Früh, SP', 0.011316717520606357),
#  ('Martin Sarbach, SP', 0.011251520861123254),
#  ('Marcel Savarioud, SP', 0.011035501447437004),
#  ('Bruno Sidler, SVP', 0.010895118722141038),
#  ('Christina Hug, Grüne', 0.010425964620000875),
#  ('Jürg Liebermann, FDP', 0.010259304409979294),
#  ('Claudia Simon, FDP', 0.009901949272535909),
#  ('Marcel Schönbächler, CVP', 0.009712937557419586),
#  ('Andreas Kirstein, AL', 0.009238144699557044),
#  ('Monika Bätschmann, Grüne', 0.008792606427278879),
#  ('Karin Rykart Sutter, Grüne', 0.008777859614854458),
#  ('Werner Sieg, SP', 0.008467246948993219),
#  ('Claudia Rabelbauer, EVP', 0.008404541267883451),
#  ('Gian von Planta, GLP', 0.008337842902948313),
#  ('Markus Kunz, Grüne', 0.00831961572245063),
#  ('Corina Gredig, GLP', 0.00794948793122726),
#  ('Urs Egger, FDP', 0.007865998878199762),
#  ('Josef Widler, CVP', 0.007753062730626757),
#  ('Peter Anderegg, EVP', 0.007619927233688916),
#  ('Monika Spring-Gross, SP', 0.007348070314604031),
#  ('Andreas Ammann, SP', 0.007063824211919398),
#  ('Pawel Silberring, SP', 0.006915057361360136),
#  ('Romeo Steiner, CVP', 0.006739530103532),
#  ('Thomas  Kappeler, CVP', 0.006635749220253038),
#  ('Franziska Graf, SP', 0.0064649530981613955),
#  ('Olivia Romanelli, AL', 0.006415570552026227),
#  ('Martin Luchsinger, GLP', 0.006342868768832692),
#  ('Luzi Rüegg, SVP', 0.006314729866018363),
#  ('Helen Glaser, SP', 0.006308761679583305),
#  ('Florian Utz, SP', 0.006092004088007194),
#  ('Ezgi Akyol, AL', 0.0059987047037896556),
#  ('Karin Weyermann, CVP', 0.005902181969289936),
#  ('Astrid Hirzel, CVP', 0.005785086163424443),
#  ('Andreas Edelmann, SP', 0.005784800357351472),
#  ('Yasmine Bourgeois, FDP', 0.005513317999051849),
#  ('Heinz Bögle, SP', 0.005513317999051849),
#  ('Thomas Schwendener, SVP', 0.005513317999051849),
#  ('Renate Fischer, SP', 0.005513317999051849),
#  ('Simone Bertogg-Baudet, Grüne', 0.005513317999051849),
#  ('Peter Marti, FDP', 0.005513317999051849),
#  ('Susann Birrer, FDP', 0.005513317999051849),
#  ('Heidi Egger, SP', 0.005513317999051849),
#  ('Arthur Bernet, SVP', 0.005513317999051849),
#  ('Marianne Aubert, SP', 0.005513317999051849),
#  ('Mathias Egloff, SP', 0.005513317999051849),
#  ('Renate Schoch, AL', 0.005513317999051849),
#  ('Richard Wolff, AL', 0.005293880839175853),
#  ('Salvatore Di Concilio, SP', 0.004856586955850586),
#  ('Andri Silberschmidt, FDP', 0.00465765599332592),
#  ('Erika Bärtschi Hafner, FDP', 0.0045050573446441455),
#  ('Stefan Urech, SVP', 0.004450034570866676),
#  ('Hansruedi Bär, SVP', 0.0043649290645468),
#  ('Guy Krayenbühl, GLP', 0.004329496582231292),
#  ('Severin Pflüger, FDP', 0.004291412540739602),
#  ('Sebastian Vogel, FDP', 0.004070996929851781),
#  ('Beat Badertscher, FDP', 0.003926847233365391),
#  ('Beatrice Reimann, SP', 0.0039200834479756995),
#  ('Kurt Maeder, CVP', 0.0037895115676056445),
#  ('Heinz Jacobi, SP', 0.0036898035731536714),
#  ('Përparim Avdili, FDP', 0.003615871734087889),
#  ('Luca Maggi, Grüne', 0.003423585963028342),
#  ('Michael Kraft, SP', 0.003365971694942799),
#  ('Davy Graf, SP', 0.003270763441561011),
#  ('Heidi Bucher-Steinegger, Grüne', 0.002839887881960189),
#  ('Paul Kleger, FDP', 0.002813094287906446),
#  ('Shaibal Roy, GLP', 0.002793945526004124),
#  ('Zilla Roose, SP', 0.0026905530692240332),
#  ('Fakir Atalay, SP', 0.002628382691628314),
#  ('Raphael Kobler, FDP', 0.0026251029338210997),
#  ('Marcel Tobler, SP', 0.0024988102495096076),
#  ('Jean-Claude Virchaux, CVP', 0.002497438215951765),
#  ('Hans Bachmann, FDP', 0.0024055181886370315),
#  ('Anton Stäbler, CVP', 0.0023195897955778744),
#  ('Martin Mächler, EVP', 0.0022591761925576915),
#  ('Hans Urs von Matt, SP', 0.002163923883492173),
#  ('Eva-Maria Würth, SP', 0.00211605779705792),
#  ('Kurt Hüssy, SVP', 0.0020823313736583865),
#  ('Simon Kälin-Werth, Grüne', 0.0020776760071787134),
#  ('Mathias Manz, SP', 0.0019975347699180955),
#  ('Myriam Barzotto, SP', 0.0019363278179952725),
#  ('Marcel Knörr, FDP', 0.0018958589935740057),
#  ('Peter Küng, SP', 0.0018945105855646264),
#  ('Elena Marti, Grüne', 0.0017843653081584044),
#  ('Alexander Brunner, FDP', 0.0017636591951335338),
#  ('Jacqueline Badran, SP', 0.001715545332289052),
#  ('Linda Bär, SP', 0.0016362336490853197),
#  ('Marc Bourgeois, FDP', 0.0016263846578379395),
#  ('Res Marti, Grüne', 0.0016243324506278168),
#  ('Andrea Leitner Verhoeven, AL', 0.0016148203166795418),
#  ('Michael Schmid, FDP', 0.0015504271270456265),
#  ('Myrtha Meuli, SP', 0.0014781640604248712),
#  ("Marcel Z'graggen, CVP", 0.001443785176236646),
#  ('Corine Mauch, SP', 0.0013732368988482507),
#  ('Marcel Müller, FDP', 0.0013491587004311376),
#  ('Urs Fehr, SVP', 0.001330692262515237),
#  ('Karin Meier-Bohrer, Grüne', 0.0013037301791413531),
#  ('Uschi Heinrich, SP', 0.0012809910139361922),
#  ('Simon Diggelmann, SP', 0.0012321645738673814),
#  ('Petek Altinay, SP', 0.0011964930256285944),
#  ('Marianne Spieler Frauenfelder, SP', 0.0011931869048002193),
#  ('Andrew Katumba, SP', 0.001054059696518191),
#  ('Ruth Ackermann, CVP', 0.0009719387271309299),
#  ('Cornelia Schaub, SVP', 0.0009181858368991537),
#  ('Kurt Haueter, SVP', 0.0009181858368991537),
#  ('Raphaela-Franziska Ulcay-Hauser, SVP', 0.0009181858368991537),
#  ('Marina Garzotto, SVP', 0.0009181858368991537),
#  ('Cäcilia Hänni-Etter, FDP', 0.0008841729712871328),
#  ('Hanspeter Kunz, EVP', 0.0008786364196628416),
#  ('Muriel Herzig, Grüne', 0.0008744197006683382),
#  ('Roger-Paul Speck, SP', 0.0008709095660759665),
#  ('Jürg Casparis, SVP', 0.0008014118669665107),
#  ('Lorenz Habicher, SVP', 0.0008014118669665107),
#  ('Felix Moser, Grüne', 0.000778071252848701),
#  ('Ruth Zollinger, FraP', 0.0007611211211857569),
#  ('Hans Diem, CVP', 0.0007553331747160103),
#  ('Mischa Morgenbesser, FDP', 0.0007267842827713321),
#  ('Kathy Steiner, Grüne', 0.0007042451575663175),
#  ('Pirmin Meyer, GLP', 0.0006726013627133385),
#  ('Doris Weber, FDP', 0.000670711686521583),
#  ('Hedy Schlatter, SVP', 0.0006695846172746203),
#  ('Michel Urben, SP', 0.00064757683627629),
#  ('André Odermatt, SP', 0.0006372865477641218),
#  ('Andrea Nüssli, SP', 0.0006302126879620599),
#  ('Esther Straub, SP', 0.000511073113262638),
#  ('Christine Stokar Gasser, SP', 0.0004758716397792489),
#  ('Rolf Kuhn, SP', 0.0004329312339090271),
#  ('Nadia Huberson, SP', 0.0003769228263419037),
#  ('Katrin Schönenberger-Meier, EVP', 0.00037608043389872304),
#  ('Bastien Girod, Grüne', 0.0003631872440548124),
#  ('Brigitte Fürer, Grüne', 0.0003608603146044237),
#  ('Barbara Wiesmann, SP', 0.00035820981021409445),
#  ('Patrick Hadi Huber, SP', 0.0003500297467665814),
#  ('Martin Abele, Grüne', 0.0003479999376200029),
#  ('Judith Bucher, SP', 0.0003450293442505805),
#  ('Marie-Therese Meier, SP', 0.0003105561175060555),
#  ('Gerhard Bosshard, EVP', 0.0002982206151000921),
#  ('Kurt Tschopp, CVP', 0.0002830266532708218),
#  ('Theresa G. Hensch-Stadelmann, FDP', 0.00026585619225718594),
#  ('Werner Furrer, SVP', 0.00026296987124335984),
#  ('Pascal Pauli, Grüne', 0.00026167915120209106),
#  ('Michèle Halser-Furrer, EVP', 0.0001752210608636082),
#  ('Marianne Dubs Früh, SP', 0.00012095046904451151),
#  ('Jonas Steiner, SP', 0.00010707577929291632),
#  ('Mark Roth, SP', 0.00010481786484773609),
#  ('Toni Baur, Grüne', 5.267501272979474e-05),
#  ('Katrin Wüthrich, SP', 2.341111676879766e-05),
#  ('Elisabeth Schoch, FDP', 1.7558337576598247e-05),
#  ('Theres Renner, FraP', 1.7558337576598247e-05),
#  ('Hanna Lienhard, FDP', 1.7558337576598247e-05),
#  ('Rosa Maino, AL', 0.0),
#  ('Hermann Aebi, Parteilos', 0.0),
#  ('Peter Püntener, GLP', 0.0),
#  ('Thomas Marthaler, SP', 0.0),
#  ('Christian Mettler, SVP', 0.0),
#  ('Rolf Walther, FDP', 0.0),
#  ('Daniel Regli, SVP', 0.0),
#  ('Susanne Brunner, SVP', 0.0),
#  ('Maya Burri-Wenger, SP', 0.0),
#  ('Oliver B. Meier, SVP', 0.0),
#  ('Jürg R. Schüepp, FDP', 0.0),
#  ('Esther Ponti-Weder, CVP', 0.0),
#  ('Bernhard Jüsi, SP', 0.0),
#  ('Erika Mägli-Fischer, SP', 0.0),
#  ('Martin Burger, SVP', 0.0),
#  ('Beat Bloch, CSP', 0.0),
#  ('Nicole Bisig, SP', 0.0),
#  ('Eva Virag Jansen, Grüne', 0.0),
#  ('Christoph Luchsinger, FDP', 0.0),
#  ('Christopher Vohdin, SVP', 0.0),
#  ('Placidus Maissen, CVP', 0.0),
#  ('Reto Vogelbacher, CVP', 0.0),
#  ('Andres Türler, FDP', 0.0),
#  ('Emil Seliner, SP', 0.0),
#  ('Rolf Müller, SVP', 0.0),
#  ('Robert Eggler, FDP', 0.0),
#  ('Mirella Wepf, SP', 0.0),
#  ('Karin Peter, SVP', 0.0),
#  ('Bruno Amacker, SVP', 0.0),
#  ('Nicole Giger, SP', 0.0),
#  ('Susanne Erdös-Schärer, SP', 0.0),
#  ('Rolf André Siegenthaler-Benz, SVP', 0.0),
#  ('Bernhard Britschgi, SVP', 0.0),
#  ('Natalie Eberle, AL', 0.0),
#  ('Fabienne Vocat, Grüne', 0.0),
#  ('Ursula Näf, SP', 0.0),
#  ('Salomon Browar, Grüne', 0.0),
#  ('Christian Aeschbach, FDP', 0.0),
#  ('Reto Dettli, SP', 0.0),
#  ('Kurt Krebs, SL', 0.0),
#  ('Nina Fehr Düsel, SVP', 0.0),
#  ('Kurt Miescher, SD', 0.0),
#  ('Kyriakos Papageorgiou, SP', 0.0),
#  ('Daniela Schicker, AL', 0.0),
#  ('Reto Rudolf, CVP', 0.0),
#  ('Guido Wick, FDP', 0.0),
#  ('Ronny Siev, GLP', 0.0),
#  ('Marco V. Camin, FDP', 0.0),
#  ('Maya Kägi Götz, SP', 0.0),
#  ('Luzia Vieli-Hardegger, LdU', 0.0),
#  ('Pablo Bünger, FDP', 0.0),
#  ('Max Müller, SVP', 0.0),
#  ('Armin W. Zenger, LdU', 0.0),
#  ('Maleica Landolt, GLP', 0.0),
#  ('Ronald Schmid, FDP', 0.0),
#  ('Monika Piesbergen, FDP', 0.0),
#  ('Heinz Schatt, SVP', 0.0),
#  ('Patrik Maillard, AL', 0.0),
#  ('Maria del Carmen Señorán, SVP', 0.0),
#  ('Andrea Widmer Graf, FDP', 0.0),
#  ('Johanna Tremp, SP', 0.0),
#  ('Kathy Riklin, CVP', 0.0),
#  ('Peter Mächler, SVP', 0.0),
#  ('Vera Ziswiler, SP', 0.0),
#  ('Claudia Rütsche, CVP', 0.0),
#  ('Martin Bürki, FDP', 0.0),
#  ('Yvonne Müller, SP', 0.0),
#  ('Armin Schilter, SVP', 0.0),
#  ('Karl Gafner, FDP', 0.0),
#  ('Hansueli Züllig, SVP', 0.0),
#  ('Doris Fiala, FDP', 0.0),
#  ('Ueli Keller, SP', 0.0),
#  ('Max Fritz, FDP', 0.0),
#  ('Christina Bellin-Isele, SP', 0.0),
#  ('Gabriela Rothenfluh, SP', 0.0),
#  ('Dominique Feuillet, SP', 0.0),
#  ('Mark Richli, SP', 0.0),
#  ('Mischa Schiwow, AL', 0.0),
#  ('Adrian Gautschi, GLP', 0.0),
#  ('Sacha Walker, GLP', 0.0),
#  ('Duri Beer, SP', 0.0),
#  ('Marco Geissbühler, SP', 0.0),
#  ('Corina Ursprung, FDP', 0.0),
#  ('Thelma Huber, FraP', 0.0),
#  ('Catrina Luchsinger Gähwiler, FDP', 0.0),
#  ('2013_0440 Protokollauszug Beschluss.pdf, 32 KB', 0.0),
#  ('2013_0440 Protokollauszug substanziell.pdf, 35 KB', 0.0),
#  ('Alexander Weber, SVP', 0.0),
#  ('Andreas Egli, FDP', 0.0),
#  ('Silvia Seiz, SP', 0.0),
#  ('Thomas Meier, SVP', 0.0),
#  ('Urs Lauffer, FDP', 0.0),
#  ('Matthias Wiesmann, GLP', 0.0),
#  ('Cordula Bieri, Grüne', 0.0),
#  ('Joachim Hagger, FDP', 0.0),
#  ('Eva Hirsiger, Grüne', 0.0),
#  ('Robert Kaeser, FDP', 0.0),
#  ('Patrick Albrecht, FDP', 0.0),
#  ('Anita Zimmerling Enkelmann, SP', 0.0),
#  ('Emil Grabherr, SVP', 0.0),
#  ('Mario Babini, Parteilos', 0.0),
#  ('Florian Blättler, SP', 0.0),
#  ('Christian Monn, GLP', 0.0),
#  ('Irene Bernhard, GLP', 0.0),
#  ('Rosemarie Berthoud, FDP', 0.0),
#  ('Fiammetta Jahreiss-Montagnani, SP', 0.0),
#  ('Muammer Kurtulmus, Grüne', 0.0),
#  ('Anna Brändle Galliker, SP', 0.0),
#  ('Andrea Hochreutener, SP', 0.0),
#  ('Jürg Ammann, Grüne', 0.0),
#  ('Renate Fässler, SP', 0.0),
#  ('Silvio Scotoni, FDP', 0.0)]

# %%
#gewichtete Zentralität – basierend auf der Idee, dass Knoten mit hohen Gewichten auch viel zur Zentrelität beitragen
eig = nx.eigenvector_centrality(Netz)
sorted(eig.items(), key=itemgetter(1), reverse=True)
# Out:
# [('Robert Schönbächler, CVP', 0.3350954205329293),
#  ('Ernst Danner, EVP', 0.3342688143207178),
#  ('Daniel Leupi, Grüne', 0.2494316354003422),
#  ('Albert Leiser, FDP', 0.22090687078801222),
#  ('Bernhard Piller, Grüne', 0.19601312067220325),
#  ('Mario Mariani, CVP', 0.18454521801548807),
#  ('Niklaus Scherr, AL', 0.17233189140657024),
#  ('Walter Angst, AL', 0.16964666380557597),
#  ('Balthasar Glättli, Grüne', 0.1690069617018739),
#  ('Pierino Cerliani, Grüne', 0.1508001879408423),
#  ('Markus Knauss, Grüne', 0.14999860069097454),
#  ('Gregor Bucher, Grüne', 0.14787469233570774),
#  ('Claudia Nielsen, SP', 0.13713112406705155),
#  ('Urs Rechsteiner, CVP', 0.1352703173110266),
#  ('Beatrice Reimann, SP', 0.13458317087780014),
#  ('Corine Mauch, SP', 0.12740479745320338),
#  ('Gerold Lauber, CVP', 0.12180496468200147),
#  ('Alexander Jäger, FDP', 0.12037274334909348),
#  ('Richard Rabelbauer, EVP', 0.11043933562647572),
#  ('Daniel Meier, CVP', 0.1092875140519709),
#  ('Marlène Butz, SP', 0.0999536555155902),
#  ('Jean-Claude Virchaux, CVP', 0.09916268122763301),
#  ('Alecs Recher, AL', 0.09729268149804422),
#  ('Christian Traber, CVP', 0.093175630193777),
#  ('Bastien Girod, Grüne', 0.0911604427267053),
#  ('Jean-Daniel Strub, SP', 0.08964706600272691),
#  ('Susi Gut, PFZ', 0.08747491239674114),
#  ('Markus Bischoff, AL', 0.08657415605885867),
#  ('Andreas Ammann, SP', 0.0824469538535371),
#  ('Marco Denoth, SP', 0.08008635170712221),
#  ('Josef Widler, CVP', 0.0791850198858779),
#  ('Hans Jörg Käppeli, SP', 0.07683447775834092),
#  ('Roger Tognella, FDP', 0.07486368191414385),
#  ('Heinz F. Steger, FDP', 0.07402628324272613),
#  ('Heinz Jacobi, SP', 0.07390525204102392),
#  ('Willy Furter, EVP', 0.07242148249579786),
#  ('André Odermatt, SP', 0.07221926541298082),
#  ('Georg Schmid, CVP', 0.07186336915162113),
#  ('Christine Seidler, SP', 0.07144711884376738),
#  ('Markus Merki, GLP', 0.0713826527761254),
#  ('Michael Baumer, FDP', 0.07068013895811506),
#  ('Jacqueline Badran, SP', 0.0693732574999679),
#  ('Ann-Catherine Nabholz, GLP', 0.06926505140202743),
#  ('Salvatore Di Concilio, SP', 0.06536137653570676),
#  ('Andreas Kirstein, AL', 0.06431859904702203),
#  ('Guido Trevisan, GLP', 0.06417495016182895),
#  ('Martin Mächler, EVP', 0.0629235958311941),
#  ('Mirella Wepf, SP', 0.06199100459127785),
#  ('Martin Sarbach, SP', 0.058213597057475364),
#  ('Claudia Rabelbauer, EVP', 0.057156989162681),
#  ('Ruth Ackermann, CVP', 0.05671387958095066),
#  ('Monika Bloch Süss, CSP', 0.05589826623908855),
#  ('Bruno Garzotto, SVP', 0.054578773150226086),
#  ('Ueli Nagel, Grüne', 0.053912053644450744),
#  ('Marianne Spieler Frauenfelder, SP', 0.053322499672474266),
#  ('Christina Schiller, AL', 0.05213241930467184),
#  ('Isabel Garcia, GLP', 0.05180581508531606),
#  ('Matthias Probst, Grüne', 0.05089532650011913),
#  ('Myrtha Meuli, SP', 0.05050076433119536),
#  ('Muriel Herzig, Grüne', 0.05023443598936978),
#  ('Joe A. Manser, SP', 0.049763422324147634),
#  ('Anton Stäbler, CVP', 0.04947507696782626),
#  ('Simone Brander, SP', 0.049454228330652016),
#  ('Peter Stähli-Barth, SP', 0.049290908556007026),
#  ('Olivia Romanelli, AL', 0.049258505323070086),
#  ('Kurt Maeder, CVP', 0.04914468247646936),
#  ('Mark Roth, SP', 0.04891625177887155),
#  ('Christoph Hug, Grüne', 0.04568975293803061),
#  ('Karin Rykart Sutter, Grüne', 0.04563625109865989),
#  ('Franziska Graf, SP', 0.04559175762760669),
#  ('Katharina Prelicz-Huber, Grüne', 0.04558716711212708),
#  ('Monika Spring-Gross, SP', 0.045344209736311335),
#  ('Gabriele Kisker, Grüne', 0.04445262885867772),
#  ('Placidus Maissen, CVP', 0.044358529534437426),
#  ('Emil Seliner, SP', 0.044358529534437426),
#  ('Bruno Wohler, SVP', 0.044089747382585795),
#  ('Rebekka Wyler, SP', 0.0439972032499949),
#  ('Alan David Sangines, SP', 0.04371343048842416),
#  ('Raphael Kobler, FDP', 0.04279918307883698),
#  ('Markus Schwyn, PFZ', 0.04254674326913451),
#  ('Peider Filli, Grüne', 0.04026086649418265),
#  ('Myriam Barzotto, SP', 0.04016436088220315),
#  ('Peter Püntener, GLP', 0.040063913474026096),
#  ('Martin Luchsinger, GLP', 0.040060886282574856),
#  ('Heinz Bögle, SP', 0.0397157564216931),
#  ('Davy Graf, SP', 0.03960357755426304),
#  ('Andres Türler, FDP', 0.03917302318065091),
#  ('Hansueli Züllig, SVP', 0.03917302318065091),
#  ('Pascal Lamprecht, SP', 0.0373142383296385),
#  ('Min Li Marti, SP', 0.036620318653733865),
#  ('Ursula Uttinger, FDP', 0.03661680625350776),
#  ('Andrea Leitner Verhoeven, AL', 0.03620921426788084),
#  ('Hedy Schlatter, SVP', 0.03605200608123699),
#  ('Ruth Anhorn, SVP', 0.03497081269887962),
#  ('Samuel Dubno, GLP', 0.034552868614402446),
#  ('Marcel Savarioud, SP', 0.034216515059804394),
#  ('Roger Liebi, SVP', 0.03319334890575475),
#  ('Markus Baumann, GLP', 0.0322374024642767),
#  ('Marcel Bührig, Grüne', 0.0321427235745854),
#  ('Markus Hungerbühler, CVP', 0.031841563967807025),
#  ('Balz Bürgisser, Grüne', 0.03123717148729785),
#  ('Doris Weber, FDP', 0.03085419150199185),
#  ('Thomas Wyss, Grüne', 0.03024938367965959),
#  ('Mischa Morgenbesser, FDP', 0.030197442601316432),
#  ('Andreas Edelmann, SP', 0.030155100220949978),
#  ('Reto Dettli, SP', 0.029878007039443252),
#  ('Christine Stokar Gasser, SP', 0.02947005258304041),
#  ('Christina Hug, Grüne', 0.028987515969740633),
#  ('Patrick Hadi Huber, SP', 0.028962832026893315),
#  ('Gian von Planta, GLP', 0.028469141630424574),
#  ('Joachim Hagger, FDP', 0.02754404817142734),
#  ('Pawel Silberring, SP', 0.027517205196778607),
#  ('Mathias Manz, SP', 0.02690322658602137),
#  ('Florian Utz, SP', 0.026696067914665545),
#  ('Helen Glaser, SP', 0.025777154677772578),
#  ('Gerhard Bosshard, EVP', 0.025589500373256618),
#  ('Urs Fehr, SVP', 0.025296351341620577),
#  ('Urs Helfenstein, SP', 0.02520553520685574),
#  ('Hanspeter Kunz, EVP', 0.02511033895299484),
#  ('Sven Sobernheim, GLP', 0.02449268589395),
#  ('Marcel Schönbächler, CVP', 0.024461936541270934),
#  ('Roger Bartholdi, SVP', 0.023217917660203518),
#  ('Maya Burri-Wenger, SP', 0.02299131582238006),
#  ('Simon Kälin-Werth, Grüne', 0.0228846913921452),
#  ('Hans Urs von Matt, SP', 0.02276264459278393),
#  ("Marcel Z'graggen, CVP", 0.022430022235479054),
#  ('Bruno Sidler, SVP', 0.0222384510234725),
#  ('Markus Kunz, Grüne', 0.02147475449285332),
#  ('Heidi Bucher-Steinegger, Grüne', 0.0213544941009942),
#  ('Bruno Amacker, SVP', 0.02112039920289372),
#  ('Andrea Nüssli, SP', 0.020531061889170314),
#  ('Theresa G. Hensch-Stadelmann, FDP', 0.020150719536411014),
#  ('Silvia Seiz, SP', 0.020145990432252424),
#  ('Renate Fässler, SP', 0.020145990432252424),
#  ('Andri Silberschmidt, FDP', 0.01913702494171278),
#  ('Hans Bachmann, FDP', 0.018536370186575755),
#  ('Peter Anderegg, EVP', 0.01850670826252818),
#  ('Martin Abele, Grüne', 0.017908344170498774),
#  ('Nicole Bisig, SP', 0.017628829069611246),
#  ('Eduard Guggenheim, AL', 0.01757621933960592),
#  ('Mauro Tuena, SVP', 0.017314495553534752),
#  ('Eva Virag Jansen, Grüne', 0.017286789960007987),
#  ('Mark Richli, SP', 0.017286789960007987),
#  ('Astrid Hirzel, CVP', 0.017255435521646316),
#  ('Claudia Simon, FDP', 0.01713603093208767),
#  ('Hansruedi Bär, SVP', 0.016476117518272212),
#  ('Rolf Kuhn, SP', 0.01626359248634727),
#  ('Susann Birrer, FDP', 0.01625308914715583),
#  ('Monika Erfigen, SVP', 0.015417017337529879),
#  ('Cornelia Schaub, SVP', 0.015203234552375355),
#  ('Kurt Haueter, SVP', 0.015203234552375355),
#  ('Raphaela-Franziska Ulcay-Hauser, SVP', 0.015203234552375355),
#  ('Marina Garzotto, SVP', 0.015203234552375355),
#  ('Brigitte Fürer, Grüne', 0.015121400615570796),
#  ('Uschi Heinrich, SP', 0.014956827305942617),
#  ('Theo Hauri, SVP', 0.014902993493433242),
#  ('Thomas  Kappeler, CVP', 0.014792559102891982),
#  ('Fakir Atalay, SP', 0.014752496846559188),
#  ('Severin Pflüger, FDP', 0.014741874508743306),
#  ('Judith Bucher, SP', 0.01449989977426973),
#  ('Oliver B. Meier, SVP', 0.014239316193164264),
#  ('Anna Brändle Galliker, SP', 0.014239316193164264),
#  ('Rosa Maino, AL', 0.014132434461562184),
#  ('Stefan Urech, SVP', 0.014072544991647482),
#  ('Kyriakos Papageorgiou, SP', 0.014071841728540292),
#  ('Michael Kraft, SP', 0.013790163625833008),
#  ('Marc Bourgeois, FDP', 0.01359747525476739),
#  ('Werner Sieg, SP', 0.013024073291844034),
#  ('Esther Ponti-Weder, CVP', 0.012910652641308445),
#  ('Richard Wolff, AL', 0.012252769904685155),
#  ('Felix Moser, Grüne', 0.012098151829412086),
#  ('Monjek Rosenheim, FDP', 0.012016487947786687),
#  ('Pascal Pauli, Grüne', 0.01194888038698181),
#  ('Marcel Müller, FDP', 0.011853848990957878),
#  ('Roger-Paul Speck, SP', 0.011208342793514002),
#  ('Dorothea Frei, SP', 0.010925405562470708),
#  ('Ruth Zollinger, FraP', 0.010894093486120734),
#  ('Thomas Marthaler, SP', 0.010892990402518558),
#  ('Fiammetta Jahreiss-Montagnani, SP', 0.010892990402518558),
#  ('Köbi Möri, Parteilos', 0.010882344523902554),
#  ('Corina Gredig, GLP', 0.01075249009915131),
#  ('Thomas Schwendener, SVP', 0.010369182196408889),
#  ('Karin Peter, SVP', 0.010227408800375162),
#  ('Bernhard Britschgi, SVP', 0.010227408800375162),
#  ('Shaibal Roy, GLP', 0.010120838104455267),
#  ('Cäcilia Hänni-Etter, FDP', 0.009778766521819386),
#  ('Romeo Steiner, CVP', 0.009648715981762708),
#  ('Guy Krayenbühl, GLP', 0.00948265792169841),
#  ('Anjushka Früh, SP', 0.009456199853857237),
#  ('Elena Marti, Grüne', 0.009433004829323601),
#  ('Guido Hüni, GLP', 0.009386598971504638),
#  ('Petek Altinay, SP', 0.009339035968658198),
#  ('Marianne Dubs Früh, SP', 0.00928162986507715),
#  ('Linda Bär, SP', 0.009099929823435098),
#  ('Luca Maggi, Grüne', 0.009020873550161979),
#  ('Hans-Ulrich Meier, FDP', 0.008988333960360698),
#  ('Zilla Roose, SP', 0.008641084323838012),
#  ('Monika Bätschmann, Grüne', 0.008624741068870992),
#  ('Ezgi Akyol, AL', 0.008569471577872046),
#  ('Katrin Schönenberger-Meier, EVP', 0.008534821068544357),
#  ('Jürg R. Schüepp, FDP', 0.008466108751380144),
#  ('Heidi Egger, SP', 0.00846041583759087),
#  ('Fabienne Vocat, Grüne', 0.008262873800754326),
#  ('Marcel Tobler, SP', 0.007787671635662011),
#  ('Beat Badertscher, FDP', 0.007682441460853779),
#  ('Peter Küng, SP', 0.00746551698635776),
#  ('Kurt Tschopp, CVP', 0.0072019449850249575),
#  ('Urs Egger, FDP', 0.007169998962549909),
#  ('Simon Diggelmann, SP', 0.0070048440815565095),
#  ('Karin Meier-Bohrer, Grüne', 0.006964210310205438),
#  ('Michael Schmid, FDP', 0.006929222838449128),
#  ('Andrew Katumba, SP', 0.006921482559845522),
#  ('Sebastian Vogel, FDP', 0.006804624549509288),
#  ('Marie-Therese Meier, SP', 0.0066148531682577415),
#  ('Bernhard Jüsi, SP', 0.006534633308666521),
#  ('Kathy Steiner, Grüne', 0.006478104574675336),
#  ('Luzi Rüegg, SVP', 0.006335422883158744),
#  ('Marco V. Camin, FDP', 0.006302542530406421),
#  ('Jürg Casparis, SVP', 0.00624870871789705),
#  ('Lorenz Habicher, SVP', 0.00624870871789705),
#  ('Përparim Avdili, FDP', 0.006209673307828837),
#  ('Katrin Wüthrich, SP', 0.0061884792396930035),
#  ('Renate Fischer, SP', 0.006140270029518433),
#  ('Paul Kleger, FDP', 0.005993169423875491),
#  ('Esther Straub, SP', 0.005954310553801416),
#  ('Dominique Feuillet, SP', 0.0059502273742787345),
#  ('Kurt Hüssy, SVP', 0.005890212077752048),
#  ('Guido Wick, FDP', 0.005817461846605411),
#  ('Max Fritz, FDP', 0.005817461846605411),
#  ('Urs Lauffer, FDP', 0.005817461846605411),
#  ('Robert Kaeser, FDP', 0.005762333505200292),
#  ('Eva-Maria Würth, SP', 0.00575068320546652),
#  ('Jonas Steiner, SP', 0.005464255397072115),
#  ('Natalie Eberle, AL', 0.005329291418491824),
#  ('Vera Ziswiler, SP', 0.005329291418491824),
#  ('Gabriela Rothenfluh, SP', 0.005329291418491824),
#  ('Alexander Brunner, FDP', 0.005248526351228961),
#  ('Sacha Walker, GLP', 0.005143372311512162),
#  ('Nicole Giger, SP', 0.005100857901533217),
#  ('Arthur Bernet, SVP', 0.005044868122163729),
#  ('Christian Mettler, SVP', 0.004975825752000194),
#  ('Martin Burger, SVP', 0.004975825752000194),
#  ('Christopher Vohdin, SVP', 0.004975825752000194),
#  ('Rolf André Siegenthaler-Benz, SVP', 0.004975825752000194),
#  ('Peter Mächler, SVP', 0.004975825752000194),
#  ('Thomas Meier, SVP', 0.004975825752000194),
#  ('Emil Grabherr, SVP', 0.004975825752000194),
#  ('Karin Weyermann, CVP', 0.00473711833394576),
#  ('Daniela Schicker, AL', 0.00470654101645034),
#  ('Duri Beer, SP', 0.00470654101645034),
#  ('Rosemarie Berthoud, FDP', 0.004642773112744324),
#  ('Renate Schoch, AL', 0.004340399298901664),
#  ('Irene Bernhard, GLP', 0.004280984507414131),
#  ('Michèle Halser-Furrer, EVP', 0.003993903110407936),
#  ('Catrina Luchsinger Gähwiler, FDP', 0.003881145106048106),
#  ('Marco Geissbühler, SP', 0.0037689672067905754),
#  ('Cordula Bieri, Grüne', 0.0037689672067905754),
#  ('Maleica Landolt, GLP', 0.0037224161740910338),
#  ('Andreas Egli, FDP', 0.0037224161740910338),
#  ('Yasmine Bourgeois, FDP', 0.003702846973222689),
#  ('Michel Urben, SP', 0.0036741501408421814),
#  ('Ursula Näf, SP', 0.003652217497751894),
#  ('Maya Kägi Götz, SP', 0.003652217497751894),
#  ('Patrik Maillard, AL', 0.003652217497751894),
#  ('Beat Bloch, CSP', 0.003536403785465297),
#  ('Jürg Liebermann, FDP', 0.0034005029281463446),
#  ('Christian Aeschbach, FDP', 0.003388808594379464),
#  ('Res Marti, Grüne', 0.00303464083227447),
#  ('Pablo Bünger, FDP', 0.0030134054253557157),
#  ('Matthias Wiesmann, GLP', 0.0029467940282408753),
#  ('Muammer Kurtulmus, Grüne', 0.0029467940282408753),
#  ('Pirmin Meyer, GLP', 0.0025342774094443527),
#  ('Marion Schmid, SP', 0.0023289708584803078),
#  ('Daniel Regli, SVP', 0.00216349890990269),
#  ('Adrian Gautschi, GLP', 0.002054955014630914),
#  ('Mario Babini, Parteilos', 0.002054955014630914),
#  ('Yvonne Müller, SP', 0.002017163288185529),
#  ('Werner Furrer, SVP', 0.0019735353484941973),
#  ('Monika Piesbergen, FDP', 0.0019000209314583446),
#  ('Marianne Aubert, SP', 0.0018278759913614032),
#  ('Christina Bellin-Isele, SP', 0.0017293129930747088),
#  ('Nadia Huberson, SP', 0.0017278378277193105),
#  ('Claudia Rütsche, CVP', 0.0015225130046055406),
#  ('Andreas J. Schlegel, FDP', 0.0014870880377508145),
#  ('Barbara Wiesmann, SP', 0.0014634103394990843),
#  ('Peter Marti, FDP', 0.0014246282455957068),
#  ('Hans Marolf, SVP', 0.001314304235097576),
#  ('Simone Bertogg-Baudet, Grüne', 0.0012949503492379617),
#  ('Heinz Schatt, SVP', 0.0012772512786518434),
#  ('Patrick Albrecht, FDP', 0.0012772512786518434),
#  ('Christoph Luchsinger, FDP', 0.001212417096667311),
#  ('Armin Schilter, SVP', 0.0011279292697538444),
#  ('Mathias Egloff, SP', 0.001112664701464912),
#  ('Eva Hirsiger, Grüne', 0.0011055219405616643),
#  ('Alexander Weber, SVP', 0.0010507549826284108),
#  ('Reto Rudolf, CVP', 0.0009890382201188706),
#  ('Kurt Miescher, SD', 0.0007410946550504621),
#  ('Martin Bürki, FDP', 0.0007178326585979639),
#  ('Kurt Krebs, SL', 0.0005901031552989148),
#  ('Nina Fehr Düsel, SVP', 0.0005537984995514586),
#  ('Thelma Huber, FraP', 0.0005074151094363987),
#  ('Susanne Brunner, SVP', 0.0004329615263131583),
#  ('Rolf Walther, FDP', 0.00039759495104794664),
#  ('Maria del Carmen Señorán, SVP', 0.000272273135341021),
#  ('Corina Ursprung, FDP', 0.000272273135341021),
#  ('Mischa Schiwow, AL', 0.0002137827851545211),
#  ('Marcel Knörr, FDP', 0.0001791301362603298),
#  ('Erika Bärtschi Hafner, FDP', 0.00017881966509235989),
#  ('Hermann Aebi, Parteilos', 0.00017474097385410844),
#  ('Robert Eggler, FDP', 0.00017391643094001483),
#  ('Karl Gafner, FDP', 0.00017391643094001483),
#  ('Doris Fiala, FDP', 0.00017391643094001483),
#  ('Silvio Scotoni, FDP', 0.0001666082833921084),
#  ('Luzia Vieli-Hardegger, LdU', 0.00015139017827859715),
#  ('Ronny Siev, GLP', 0.00013009685581275346),
#  ('Hans Diem, CVP', 4.188534726091786e-05),
#  ('Toni Baur, Grüne', 2.824446599230836e-16),
#  ('Erika Mägli-Fischer, SP', 1.6306950043776458e-16),
#  ('Salomon Browar, Grüne', 1.6306950043776458e-16),
#  ('Ueli Keller, SP', 1.6306950043776458e-16),
#  ('Elisabeth Schoch, FDP', 8.850482604187882e-18),
#  ('Theres Renner, FraP', 8.850482604187882e-18),
#  ('Hanna Lienhard, FDP', 8.850482604187882e-18),
#  ('Reto Vogelbacher, CVP', 6.258236266194827e-18),
#  ('Rolf Müller, SVP', 6.258236266194827e-18),
#  ('Susanne Erdös-Schärer, SP', 6.258236266194827e-18),
#  ('Ronald Schmid, FDP', 6.258236266194827e-18),
#  ('Andrea Widmer Graf, FDP', 6.258236266194827e-18),
#  ('Anita Zimmerling Enkelmann, SP', 6.258236266194827e-18),
#  ('Max Müller, SVP', 4.5507988737482774e-20),
#  ('Armin W. Zenger, LdU', 4.5507988737482774e-20),
#  ('Johanna Tremp, SP', 4.5507988737482774e-20),
#  ('Kathy Riklin, CVP', 4.5507988737482774e-20),
#  ('2013_0440 Protokollauszug Beschluss.pdf, 32 KB', 4.5507988737482774e-20),
#  ('2013_0440 Protokollauszug substanziell.pdf, 35 KB', 4.5507988737482774e-20),
#  ('Florian Blättler, SP', 4.5507988737482774e-20),
#  ('Christian Monn, GLP', 4.5507988737482774e-20),
#  ('Andrea Hochreutener, SP', 4.5507988737482774e-20),
#  ('Jürg Ammann, Grüne', 4.5507988737482774e-20)]

# %%
import pandas as pd
import seaborn as sns  #Seaborn ist Visualisierungspaket für Pandas

centrality_measures = {
    'degree': degc,
    'betweenness': bet,
    'closeness': clos,
    'eigenvector': eig,
}
centrality = pd.DataFrame(centrality_measures)
centrality.sort_values(by="eigenvector", ascending=False).head(10)
# Out:
#                             degree  betweenness  closeness  eigenvector
# Robert Schönbächler, CVP  0.076923     0.107607   0.320836     0.335095
# Ernst Danner, EVP         0.073964     0.126569   0.324381     0.334269
# Daniel Leupi, Grüne       0.047337     0.042140   0.302333     0.249432
# Albert Leiser, FDP        0.038462     0.035015   0.314310     0.220907
# Bernhard Piller, Grüne    0.047337     0.047623   0.302022     0.196013
# Mario Mariani, CVP        0.053254     0.066792   0.313303     0.184545
# Niklaus Scherr, AL        0.038462     0.039377   0.290371     0.172332
# Walter Angst, AL          0.041420     0.040439   0.291524     0.169647
# Balthasar Glättli, Grüne  0.044379     0.032910   0.288942     0.169007
# Pierino Cerliani, Grüne   0.032544     0.028250   0.293272     0.150800

# %%
sns.pairplot(centrality)

# %% [markdown]
# ### 2. Etwas raffinierterer Anlauf
# Jetzt wollen wir...
# - die nodes mit einer Partei versehen
# - die edges mit einem Datum und einem Departement

# %%
#dazu brauchen datetime:
from datetime import datetime

# %%
file = open("Dataframe_bereinigt_parteiuebergreifend.csv", mode="r")
df2=pd.read_csv(file)
df2 = df2.set_index("Unnamed: 0")

# %%
#WIr beschränken uns, das Jahr hier rauszuholen, weil es in der Datumszeile Fehle hat:
df2["Jahr"] = df2["Geschäft"]
df2["Jahr"] = df2["Jahr"].apply(lambda x: x.split("/")[0])
df2["Jahr"]= pd.to_datetime(df2["Jahr"], format="%Y")
df2
# Out:
#                  Datum  Geschäft     Einreichender 1 Partei 1  \
# Unnamed: 0
# 0           25.11.2009  2009/562          Kurt Hüssy      SVP
# 1            21.8.2002  2002/289       Markus Schwyn      PFZ
# 2             3.5.2006  2006/134  Richard Rabelbauer      EVP
# 3           26.05.2010   2008/16       Rebekka Wyler       SP
# 4            30.8.2000  2000/415       Markus Schwyn      PFZ
# ...                ...       ...                 ...      ...
# 953           9.1.2008    2008/3       Joe A. Manser       SP
# 954           9.7.1997  1997/284      Silvio Scotoni      FDP
# 955           7.4.2004  2004/202        Alecs Recher       AL
# 956         25.11.2009  2009/547      André Odermatt       SP
# 957          3.11.2004  2004/570            Susi Gut      PFZ
#
#                 Einreichender 2 Partei 2  \
# Unnamed: 0
# 0                Peter Anderegg      EVP
# 1                Monika Erfigen      SVP
# 2           Robert Schönbächler      CVP
# 3              Pierino Cerliani    Grüne
# 4                   Mauro Tuena      SVP
# ...                         ...      ...
# 953               Mario Mariani      CVP
# 954                 Peter Marti      FDP
# 955               Muriel Herzig    Grüne
# 956                Daniel Leupi    Grüne
# 957             Roger Bartholdi      SVP
#
#                                              Departement       Jahr
# Unnamed: 0
# 0                                Polizeidepartement (PD) 2009-01-01
# 1                               Hochbaudepartement (HBD) 2002-01-01
# 2           Departement der Industriellen Betriebe (DIB) 2006-01-01
# 3                                                    NaN 2008-01-01
# 4                                 Sozialdepartement (SD) 2000-01-01
# ...                                                  ...        ...
# 953                           Präsidialdepartement (PRD) 2008-01-01
# 954                              Polizeidepartement (PD) 1997-01-01
# 955                               Sozialdepartement (SD) 2004-01-01
# 956                                                  NaN 2009-01-01
# 957            Tiefbau- und Entsorgungsdepartement (TED) 2004-01-01
#
# [958 rows x 8 columns]

# %%
#Als erstes ziehen wir die Personen as knodes raus und verleiehen ihnen das Attribut "Partei"

Netz2 = nx.Graph()
for a in range(0,(len(df2)-1)):
    Person1 = str(df2.loc[a]["Einreichender 1"])
    Person2 = str(df2.loc[a]["Einreichender 2"])
    Partei1 = str(df2.loc[a]["Partei 1"])
    Partei2 = str(df2.loc[a]["Partei 2"])
    Netz2.add_node(Person1, Partei = Partei1)
    Netz2.add_node(Person2, Partei = Partei2)

# %%
#Test:
print(list(Netz2.nodes(data='Partei')))
# Out:
# [('Kurt Hüssy', 'SVP'), ('Peter Anderegg', 'EVP'), ('Markus Schwyn', 'PFZ'), ('Monika Erfigen', 'SVP'), ('Richard Rabelbauer', 'EVP'), ('Robert Schönbächler', 'CVP'), ('Rebekka Wyler', 'SP'), ('Pierino Cerliani', 'Grüne'), ('Mauro Tuena', 'SVP'), ('Mario Mariani', 'CVP'), ('Muriel Herzig', 'Grüne'), ('Susi Gut', 'PFZ'), ('Roger Liebi', 'SVP'), ('Ezgi Akyol', 'AL'), ('Anjushka Früh', 'SP'), ('Ernst Danner', 'EVP'), ('Raphael Kobler', 'FDP'), ('Corine Mauch', 'SP'), ('Albert Leiser', 'FDP'), ('Matthias Probst', 'Grüne'), ('Guido Hüni', 'GLP'), ('Köbi Möri', 'Parteilos'), ('Hansruedi Bär', 'SVP'), ('Cäcilia Hänni-Etter', 'FDP'), ('Markus Hungerbühler', 'CVP'), ('Katrin Schönenberger-Meier', 'EVP'), ('Thomas  Kappeler', 'CVP'), ('Alan David Sangines', 'SP'), ('Daniel Leupi', 'Grüne'), ('Christian Traber', 'CVP'), ('Balz Bürgisser', 'Grüne'), ('Rosa Maino', 'AL'), ('Cornelia Schaub', 'SVP'), ('Alecs Recher', 'AL'), ('Peider Filli', 'Grüne'), ('Ursula Uttinger', 'FDP'), ('Marco Denoth', 'SP'), ('Christine Seidler', 'SP'), ('Ueli Nagel', 'Grüne'), ('Markus Baumann', 'GLP'), ('Yasmine Bourgeois', 'FDP'), ('Olivia Romanelli', 'AL'), ('Gabriele Kisker', 'Grüne'), ('Jonas Steiner', 'SP'), ('Peter Küng', 'SP'), ('Gian von Planta', 'GLP'), ('Daniel Meier', 'CVP'), ('Heinz Jacobi', 'SP'), ('Isabel Garcia', 'GLP'), ('Hermann Aebi', 'Parteilos'), ('Hans Marolf', 'SVP'), ('Peter Püntener', 'GLP'), ('Bruno Wohler', 'SVP'), ('Thomas Wyss', 'Grüne'), ('Marlène Butz', 'SP'), ('Jürg Liebermann', 'FDP'), ('Monjek Rosenheim', 'FDP'), ('Roger Tognella', 'FDP'), ('Heinz F. Steger', 'FDP'), ('Bernhard Piller', 'Grüne'), ('Judith Bucher', 'SP'), ('Thomas Marthaler', 'SP'), ('Pascal Lamprecht', 'SP'), ('Christian Mettler', 'SVP'), ('Rolf Walther', 'FDP'), ('Marcel Schönbächler', 'CVP'), ('Daniel Regli', 'SVP'), ('Walter Angst', 'AL'), ('Jean-Claude Virchaux', 'CVP'), ('Dorothea Frei', 'SP'), ('Markus Knauss', 'Grüne'), ('Guido Trevisan', 'GLP'), ('Marcel Tobler', 'SP'), ('Werner Furrer', 'SVP'), ('Paul Kleger', 'FDP'), ('Gerold Lauber', 'CVP'), ('Samuel Dubno', 'GLP'), ('Heinz Bögle', 'SP'), ('Alexander Brunner', 'FDP'), ('Shaibal Roy', 'GLP'), ('Ann-Catherine Nabholz', 'GLP'), ('Hanspeter Kunz', 'EVP'), ('Susanne Brunner', 'SVP'), ('Maya Burri-Wenger', 'SP'), ('Oliver B. Meier', 'SVP'), ('Simon Kälin-Werth', 'Grüne'), ('Bastien Girod', 'Grüne'), ('Jürg R. Schüepp', 'FDP'), ('Willy Furter', 'EVP'), ('Esther Straub', 'SP'), ('Esther Ponti-Weder', 'CVP'), ('Jean-Daniel Strub', 'SP'), ('Andreas Kirstein', 'AL'), ('Simone Brander', 'SP'), ('Sven Sobernheim', 'GLP'), ('Andri Silberschmidt', 'FDP'), ('Urs Rechsteiner', 'CVP'), ('Christoph Hug', 'Grüne'), ('Marie-Therese Meier', 'SP'), ('Gregor Bucher', 'Grüne'), ('Patrick Hadi Huber', 'SP'), ('Eduard Guggenheim', 'AL'), ('Marcel Bührig', 'Grüne'), ('Ruth Ackermann', 'CVP'), ('Monika Bloch Süss', 'CSP'), ('Myrtha Meuli', 'SP'), ('Hans Bachmann', 'FDP'), ('Bernhard Jüsi', 'SP'), ('Brigitte Fürer', 'Grüne'), ('Hans Urs von Matt', 'SP'), ("Marcel Z'graggen", 'CVP'), ('Toni Baur', 'Grüne'), ('Erika Mägli-Fischer', 'SP'), ('Claudia Rabelbauer', 'EVP'), ('Elena Marti', 'Grüne'), ('Urs Helfenstein', 'SP'), ('Martin Burger', 'SVP'), ('Luca Maggi', 'Grüne'), ('Christina Schiller', 'AL'), ('Beat Bloch', 'CSP'), ('Bruno Sidler', 'SVP'), ('Nicole Bisig', 'SP'), ('Marcel Müller', 'FDP'), ('Eva Virag Jansen', 'Grüne'), ('Thomas Schwendener', 'SVP'), ('Christoph Luchsinger', 'FDP'), ('Niklaus Scherr', 'AL'), ('Christopher Vohdin', 'SVP'), ('Katrin Wüthrich', 'SP'), ('Jacqueline Badran', 'SP'), ('Balthasar Glättli', 'Grüne'), ('Jürg Casparis', 'SVP'), ('Alexander Jäger', 'FDP'), ('Fakir Atalay', 'SP'), ('Placidus Maissen', 'CVP'), ('Theo Hauri', 'SVP'), ('Markus Bischoff', 'AL'), ('Renate Fischer', 'SP'), ('Heidi Bucher-Steinegger', 'Grüne'), ('Davy Graf', 'SP'), ('Reto Vogelbacher', 'CVP'), ('Elisabeth Schoch', 'FDP'), ('Eva-Maria Würth', 'SP'), ('Karin Rykart Sutter', 'Grüne'), ('Martin Sarbach', 'SP'), ('Roger Bartholdi', 'S ...

# %%
#Als zweites machen wir die edges und versehen sie mit eindem datetime-Datum:
for a in range(0,(len(df2)-1)):
    Person1 = str(df2.loc[a]["Einreichender 1"])
    Person2 = str(df2.loc[a]["Einreichender 2"])
    Jahr = str(df2.loc[a]["Jahr"])
    Departement = str(df2.loc[a]["Departement"])
    
    #Beziehungen, die mehrmals vorkommen, sollte gewichtet werden (weight +1)
    if Netz2.has_edge(Person1, Person2):
        Netz2[Person1][Person2]["weight"] += 1
    else:
        Netz2.add_edge(Person1, Person2, date = Jahr, thema = Departement, weight=1)

# %%
print(nx.info(Netz2))
# Out:
# Name:
# Type: Graph
# Number of nodes: 339
# Number of edges: 636
# Average degree:   3.7522

# %%
#scheint zu funktionieren!
Netz2.edges["Susi Gut", "Roger Bartholdi"]['weight']
# Out:
# 6

# %%
#Problem: Wenn die mehrmals in versch. Departementen zusammengearbeitet haben, wird nur ein Wert mitgeliefert...
Netz2.edges["Susi Gut", "Roger Bartholdi"]['thema']
# Out:
# 'Gesundheits- und Umweltdepartement (GUD)'

# %%
#Und speichern:
nx.write_gexf(Netz, "Politikerpaare_raffiniert.gexf")
