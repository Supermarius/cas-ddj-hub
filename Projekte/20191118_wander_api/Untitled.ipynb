# %%
import requests
import pandas as pd

# %%
url = "https://zentur.com/api/"
inhalt = requests.get(url, headers={'Authorization': "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImtpZCI6IlF6VXpSamhCTXpBd1JVWXdOell5TXpNNE1rWXhORE5DTnpKR01UZENORUkxUVVZelFUbEVNQSJ9.....Xsu6G49ixdCYqoxmFKwHAnHqZAsdTtdFrpmriiKari3j_2gfp3VFpB4RkPtw6ZReB-cdkb62C0ROSGwKkewGt3_p59MP_e908H89KCX6uYBHD_FuklW40_OToTthYLoMHS1wE6V_zUnyCAlvc3W4J-fMdD1xlSj6fhg6TzT6WWUKsmlF3gedwwhc2xt8BphDmNE4wv8pwwGLate3aoZmSh0YH3TJWJJDa2OjDko1zjJdZQmod1YJRGVGdaplxpyywrz2dt2Y20rZ__Q_ixOU4k4cGh5o6PemTE0N-Fq4g87O4KBftFXWHP9n3j2ncuCwDyMvZxWP6621JkdZOdorFw"})

# %%
dict = inhalt.json()

# %% [markdown]
# ### Hier sind zunächst mal meine Userdaten drin

# %%
dict_user = dict["user"]

# %%
#level2
for key in dict_user:
    print(key)
# Out:
# uid
# head
# email
# a0id
# level
# invitedAt
# invitedByUid
# link
# fotoVoteCount

# %%
#Level3 – hier sind die Daten drin
dict_mail = dict_user["head"]
for key in dict_mail:
    print(key)
# Out:
# hid
# code
# name
# fid
# crop
# link
# iconFotoLink
# iconLink
# trips
# arrDate
# depDate
# bounds
# dates
# dst
# ele
# modes
# flags
# hikeMins

# %%
#aneinander gekettet
dict["user"]["head"]["flags"]
# Out:
# {'resto': 62,
#  'camp': 57,
#  'fire': 49,
#  'night': 72,
#  'pass': 56,
#  'border': 10,
#  'lake': 26,
#  'station': 58,
#  'house': 7,
#  'fondue': 7,
#  'shop': 9}

# %%
for key in dict["user"]["head"]["trips"]:
    print(key)

# %%
#Daten von Trip1
dict["user"]["head"]["trips"]["355768578"]
# Out:
# {'bounds': [[9.695309, 46.237277], [9.821908, 46.403166]],
#  'dst': {'len': 35785, 'min': 0, 'max': 35785},
#  'ele': {'mup': 3058.3370999999997,
#   'mdn': 2771.6710999999996,
#   'min': 1651.5322,
#   'max': 2771},
#  'depDate': '2018-07-06',
#  'arrDate': '2018-07-09',
#  'dates': ['2018-07-06', '2018-07-07', '2018-07-08', '2018-07-09'],
#  'hids': ['445922223',
#   '683451080',
#   '356636038',
#   '457655925',
#   '518936421',
#   '177966929',
#   '493439369',
#   '161503618'],
#  'flags': {'resto': 4,
#   'camp': 4,
#   'fire': 4,
#   'night': 4,
#   'pass': 2,
#   'border': 1,
#   'lake': 2},
#  'dids': ['820236830', '663709315', '372950606', '442932230'],
#  'hikeMins': 863.7299999999999,
#  'modes': {'hike': {'bounds': [[9.695309, 46.237277], [9.821908, 46.403166]],
#    'dst': {'len': 35785, 'min': 0, 'max': 35785},
#    'ele': {'mup': 3058.3370999999997,
#     'mdn': 2771.6710999999996,
#     'min': 1651.5322,
#     'max': 2771},
#    'depDate': '2018-07-06',
# ...

# %% [markdown]
# ### Und so greife ich die Daten der anderen User ab:

# %%
url2 = dict["headsLink"]
heads = requests.get(url2, headers={'Authorization': "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImtpZCI6IlF6VXpSamhCTXpBd1JVWXdOell5TXpNNE1rWXhORE5DTnpKR01UZENORUkxUVVZelFUbEVNQSJ9.....Xsu6G49ixdCYqoxmFKwHAnHqZAsdTtdFrpmriiKari3j_2gfp3VFpB4RkPtw6ZReB-cdkb62C0ROSGwKkewGt3_p59MP_e908H89KCX6uYBHD_FuklW40_OToTthYLoMHS1wE6V_zUnyCAlvc3W4J-fMdD1xlSj6fhg6TzT6WWUKsmlF3gedwwhc2xt8BphDmNE4wv8pwwGLate3aoZmSh0YH3TJWJJDa2OjDko1zjJdZQmod1YJRGVGdaplxpyywrz2dt2Y20rZ__Q_ixOU4k4cGh5o6PemTE0N-Fq4g87O4KBftFXWHP9n3j2ncuCwDyMvZxWP6621JkdZOdorFw"})
wandervoegel = heads.json()["items"]

# %%
for key in wandervoegel:
    print(key["name"])
# Out:
# Me
# Märe
# Lee
# Ivo
# Jochen
# Ruedi
# Peti
# Baf
# David
# Römi
# Mink
# Chrigi
# Marco
# Tom
# Fritz
# Luki
# Sebi
# Dave
# Adi
# Päde

# %%
#Wanderer Nummer 1 (Me)
for key in wandervoegel[0]:
    print(key)
# Out:
# hid
# code
# name
# fid
# crop
# link
# iconFotoLink
# iconLink
# trips
# arrDate
# depDate
# bounds
# dates
# dst
# ele
# modes
# flags
# hikeMins

# %%
#hier seine kompletten Höhenmeter: 
wandervoegel[0]["ele"]
# Out:
# {'mup': 72886.89149999998, 'mdn': 71334.6861, 'min': 212.1, 'max': 2986.776}

# %%
#hier seine komplette Distanz: 
wandervoegel[0]["dst"]
# Out:
# {'len': 1191728, 'min': 0, 'max': 171489}

# %%
wandervoegel[0]["fid"]
# Out:
# '158007244'

# %%
#und seine Trips (die haben offenbar eine gleichbleibende id ("tid") – das hier ist etwa der 2018er: 355768578:
wandervoegel[0]["trips"]
for key in wandervoegel[0]["trips"]:
    print(key)
# Out:
# 355768578
# 373644433
# 386221906
# 412294949
# 422854585
# 440974925
# 460166639
# 512045511
# 672453501
# 805406498
# 862071326
# 899338426

# %%
wandervoegel[0]["trips"]["355768578"]
# Out:
# {'bounds': [[9.663696, 46.237277], [9.821908, 46.403166]],
#  'dst': {'len': 50384, 'min': 0, 'max': 50384},
#  'ele': {'mup': 4786.4629,
#   'mdn': 4207.8279,
#   'min': 1651.5322,
#   'max': 2950.413},
#  'depDate': '2018-07-06',
#  'arrDate': '2018-07-11',
#  'dates': ['2018-07-06',
#   '2018-07-07',
#   '2018-07-08',
#   '2018-07-09',
#   '2018-07-10',
#   '2018-07-11'],
#  'hids': ['445922223',
#   '683451080',
#   '356636038',
#   '457655925',
#   '518936421',
#   '177966929',
#   '493439369',
#   '161503618'],
#  'flags': {'resto': 6,
#   'camp': 4,
#   'fire': 4,
#   'night': 6,
#   'pass': 6,
#   'border': 1,
#   'lake': 2,
#   'house': 2,
#   'fondue': 1},
#  'dids': ['820236830',
#   '663709315',
#   '372950606',
#   '442932230',
#   '415947725',
#   '446892441'],
#  'hikeMins': 1258.8999999999999,
#  'modes': {'hike': {'bounds': [[9.663696, 46.237277], [9.821908, 46.403166]],
#    'dst': {'len': 50384, 'min': 0, 'max': 50384},
#    'ele': {'mup': 4786.4629,
# ...

# %%
# das hier sind seine Leistungen währen des 2018er_Trips:
print(wandervoegel[0]["trips"]["355768578"]["dst"], 
      wandervoegel[0]["trips"]["355768578"]["ele"], 
      wandervoegel[0]["trips"]["355768578"]["hikeMins"])
# Out:
# {'len': 50384, 'min': 0, 'max': 50384} {'mup': 4786.4629, 'mdn': 4207.8279, 'min': 1651.5322, 'max': 2950.413} 1258.8999999999999

# %% [markdown]
# ### Hier sind die Trips-Daten drin:

# %%
url3 = dict["tripsLink"]
trips = requests.get(url3, headers={'Authorization': "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImtpZCI6IlF6VXpSamhCTXpBd1JVWXdOell5TXpNNE1rWXhORE5DTnpKR01UZENORUkxUVVZelFUbEVNQSJ9.....Xsu6G49ixdCYqoxmFKwHAnHqZAsdTtdFrpmriiKari3j_2gfp3VFpB4RkPtw6ZReB-cdkb62C0ROSGwKkewGt3_p59MP_e908H89KCX6uYBHD_FuklW40_OToTthYLoMHS1wE6V_zUnyCAlvc3W4J-fMdD1xlSj6fhg6TzT6WWUKsmlF3gedwwhc2xt8BphDmNE4wv8pwwGLate3aoZmSh0YH3TJWJJDa2OjDko1zjJdZQmod1YJRGVGdaplxpyywrz2dt2Y20rZ__Q_ixOU4k4cGh5o6PemTE0N-Fq4g87O4KBftFXWHP9n3j2ncuCwDyMvZxWP6621JkdZOdorFw"})

#In dieser Dict-Liste sind die Daten aller Trips drin:
trips.json()["items"]
# Out:
# [{'tid': '422854585',
#   'title': '2014',
#   'tripDepDate': '2014-07-25',
#   'desc': 'Gotthardpass - Saas-Almagell',
#   'depDate': '2014-07-25',
#   'depTime': None,
#   'arrDate': '2014-08-01',
#   'arrTime': None,
#   'dates': ['2014-07-25',
#    '2014-07-26',
#    '2014-07-27',
#    '2014-07-28',
#    '2014-07-29',
#    '2014-07-30',
#    '2014-07-31',
#    '2014-08-01'],
#   'dids': ['502702720',
#    '202692042',
#    '549605337',
#    '394803215',
#    '869294128',
#    '172419339',
#    '845005028',
#    '265648885'],
#   'fid': '698348194',
#   'bounds': [[7.957704, 46.094265], [8.56723, 46.555515]],
#   'mode': 'hike',
#   'modes': {'hike': {'bounds': [[7.957704, 46.094265], [8.56723, 46.555515]],
#     'dst': {'len': 110852, 'min': 0, 'max': 110852},
#     'ele': {'mup': 6258.2878,
#      'mdn': 6678.001800000001,
#      'min': 847.8737,
#      'max': 3263.425},
#     'depDate': '2014-07-25',
#     'arrDate': '2014-08-01',
#     'dates': ['2014-07-25',
# ...

# %%
tripliste = trips.json()["items"]

for trip in tripliste:
    print (trip["title"], trip["desc"])
# Out:
# 2014 Gotthardpass - Saas-Almagell
# 2015 Lac des Dix - Col de Balme
# 2016 Mauvoisin - Mattmark
# 2017 Krummenau - Cumpadials
# 2018 Maloja - Novate Mezzola
# 2013 Säntis - Lavin
# 2012 Brünig - Tierfehd
# 2011 Piotta - Mulegns
# 2010 Meiringen - Iffigenalp
# 2020 Klosters - Soglio
# 2009 Fiesch - Someo
# 2008 Scuol - Valmalenco
# 2019 Cortaccio - Biasca
# 2007 Zürich - Cavergno
# 2019 Brissago - Bodio
